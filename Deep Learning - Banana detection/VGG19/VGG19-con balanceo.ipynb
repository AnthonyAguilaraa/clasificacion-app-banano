# %% [markdown]
# 1. Importación de librerías

# %%
import os
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import (confusion_matrix, classification_report, accuracy_score,
                             precision_score, recall_score, f1_score, roc_auc_score)
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Ignorar warnings para limpieza del output
import warnings
warnings.filterwarnings('ignore')

print(f"TensorFlow Version: {tf.__version__}")
print(f"NumPy Version: {np.__version__}")
# Out:
# TensorFlow Version: 2.19.0
# NumPy Version: 2.0.2

# %% [markdown]
# 2. Configuración del entorno

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Semillas para reproducibilidad
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)

# Configuración de GPU
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"✅ GPU detectada: {len(gpus)} disponible(s)")
    except RuntimeError as e:
        print(e)
else:
    print("⚠️ No se detectó GPU. El entrenamiento será lento.")

# Parámetros Globales
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
CHANNELS = 3
INPUT_SHAPE = IMG_SIZE + (CHANNELS,)
NUM_EPOCHS_HEAD = 5    # Épocas fase 1 (cabeza)
NUM_EPOCHS_FINE = 15   # Épocas fase 2 (fine-tuning)

BASE_DIR = "/content/drive/MyDrive/Dataset" 
TRAIN_DIR = os.path.join(BASE_DIR, "Train")
VAL_DIR   = os.path.join(BASE_DIR, "Validation")
TEST_DIR  = os.path.join(BASE_DIR, "Test")
MODELS_DIR = "/content/drive/MyDrive/Entrenamiento con balanceo/VGG19"
os.makedirs(MODELS_DIR, exist_ok=True)
BEST_MODEL_PATH = os.path.join(MODELS_DIR, "banano_VGG19_best_scientific.keras")
# Out:
# ✅ GPU detectada: 1 disponible(s)

# %% [markdown]
# 3. Carga y exploración del dataset

# %%
# Carga de datasets usando image_dataset_from_directory
train_ds = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR,
    labels='inferred',
    label_mode='categorical',
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=SEED
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    VAL_DIR,
    labels='inferred',
    label_mode='categorical',
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False,
    seed=SEED
)

test_ds = tf.keras.utils.image_dataset_from_directory(
    TEST_DIR,
    labels='inferred',
    label_mode='categorical',
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False,
    seed=SEED
)

class_names = train_ds.class_names
num_classes = len(class_names)

print(f"\n🏷️ Clases detectadas ({num_classes}): {class_names}")

# Tabla de Support (Conteo de muestras)
def count_samples(directory, class_names):
    counts = []
    for cls in class_names:
        path = os.path.join(directory, cls)
        if os.path.exists(path):
            counts.append(len(os.listdir(path)))
        else:
            counts.append(0)
    return counts

train_counts = count_samples(TRAIN_DIR, class_names)
val_counts = count_samples(VAL_DIR, class_names)
test_counts = count_samples(TEST_DIR, class_names)

df_support = pd.DataFrame({
    'Clase': class_names,
    'Train Samples': train_counts,
    'Validation Samples': val_counts,
    'Test Samples': test_counts
})

# Gráfico de distribución
plt.figure(figsize=(12, 5))
x = np.arange(len(class_names))
width = 0.25
plt.bar(x - width, train_counts, width, label='Train', color='#1f77b4')
plt.bar(x, val_counts, width, label='Validation', color='#ff7f0e')
plt.bar(x + width, test_counts, width, label='Test', color='#2ca02c')
plt.xticks(x, class_names, rotation=45)
plt.ylabel('Número de imágenes')
plt.title('Distribución de Muestras por Clase')
plt.legend()
plt.tight_layout()
plt.show()

display(df_support)
# Out:
# Found 3500 files belonging to 7 classes.
# Found 350 files belonging to 7 classes.
# Found 350 files belonging to 7 classes.
#
# 🏷️ Clases detectadas (7): ['apto', 'cascara_partida', 'cicatriz_golpe', 'corte_cuchareta', 'mal_formaciones', 'marca_madurez', 'plaga_enfermedades']
#                 Clase  Train Samples  Validation Samples  Test Samples
# 0                apto            500                  50            50
# 1     cascara_partida            500                  50            50
# 2      cicatriz_golpe            500                  50            50
# 3     corte_cuchareta            500                  50            50
# 4     mal_formaciones            500                  50            50
# 5       marca_madurez            500                  50            50
# 6  plaga_enfermedades            500                  50            50

# %% [markdown]
# TABLA 1: DISTRIBUCIÓN POR CLASES DETALLADA

# %%
# ==========================================
# TABLA 1: DISTRIBUCIÓN POR CLASES DETALLADA
# ==========================================

# Calcular totales por clase
total_per_class = [t + v + te for t, v, te in zip(train_counts, val_counts, test_counts)]
total_dataset = sum(total_per_class)

# Calcular porcentajes
percentages = [f"{(count/total_dataset)*100:.2f}%" for count in total_per_class]

df_distribution = pd.DataFrame({
    'Clase (Etiqueta)': class_names,
    'Entrenamiento (Train)': train_counts,
    'Validación (Val)': val_counts,
    'Prueba (Test)': test_counts,
    'Total Muestras': total_per_class,
    'Distribución (%)': percentages
})

# Añadir fila de totales
row_total = pd.DataFrame({
    'Clase (Etiqueta)': ['TOTAL'],
    'Entrenamiento (Train)': [sum(train_counts)],
    'Validación (Val)': [sum(val_counts)],
    'Prueba (Test)': [sum(test_counts)],
    'Total Muestras': [total_dataset],
    'Distribución (%)': ['100%']
})

df_distribution = pd.concat([df_distribution, row_total], ignore_index=True)

print("\n📋 Tabla 1: Distribución del Dataset por Clases")
display(df_distribution)
# Out:
# 📋 Tabla 1: Distribución del Dataset por Clases
#      Clase (Etiqueta)  Entrenamiento (Train)  Validación (Val)  Prueba (Test)  \
# 0                apto                    500                50             50
# 1     cascara_partida                    500                50             50
# 2      cicatriz_golpe                    500                50             50
# 3     corte_cuchareta                    500                50             50
# 4     mal_formaciones                    500                50             50
# 5       marca_madurez                    500                50             50
# 6  plaga_enfermedades                    500                50             50
# 7               TOTAL                   3500               350            350
#
#    Total Muestras Distribución (%)
# 0             600           14.29%
# 1             600           14.29%
# 2             600           14.29%
# 3             600           14.29%
# 4             600           14.29%
# 5             600           14.29%
# 6             600           14.29%
# 7            4200             100%

# %% [markdown]
# 4. Preprocesamiento de datos

# %%
# Optimización de carga (Prefetching)
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)

# Capa de Data Augmentation dentro del modelo 
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
    layers.RandomTranslation(0.1, 0.1),
    layers.RandomContrast(0.1),
    layers.RandomBrightness(0.1)
], name="Data_Augmentation")

print("✅ Pipeline de datos configurado.")
# Out:
# ✅ Pipeline de datos configurado.

# %%
# ==================================================
# TABLA 2: TÉCNICAS DE PREPROCESAMIENTO APLICADAS
# ==================================================
preprocessing_data = [
    ["Redimensionamiento (Resize)", f"{IMG_SIZE[0]}x{IMG_SIZE[1]} píxeles", "Estandarización de entrada"],
    ["Espacio de Color", "RGB (3 canales)", "Formato estándar de imagen"],
    ["Normalización", "Interna (EfficientNet)", "EfficientNetB0 incluye capa de preprocesamiento (espera rangos [0-255])"],
    ["Batching", f"{BATCH_SIZE} imágenes por lote", "Optimización de memoria GPU"],
    ["Prefetching", "Autotune (Buffer dinámico)", "Carga asíncrona CPU-GPU"],
    ["Caching", "Memoria/Disco", "Evita recargar imágenes en cada época"]
]

df_preprocessing = pd.DataFrame(preprocessing_data, columns=["Técnica", "Configuración", "Justificación"])

print("\n🛠️ Tabla 2: Técnicas de Preprocesamiento")
display(df_preprocessing)


# ==================================================
# TABLA 3: TÉCNICAS DE AUMENTO DE DATOS (DATA AUGMENTATION)
# ==================================================
augmentation_data = [
    ["Random Flip", "Horizontal", "Simula espejo (izquierda/derecha)"],
    ["Random Rotation", "Factor 0.1 (±10%)", "Simula variaciones en el ángulo de captura"],
    ["Random Zoom", "Factor 0.1 (±10%)", "Simula distancia de la cámara"],
    ["Random Translation", "Height/Width 0.1", "Simula desplazamiento del objeto en el encuadre"],
    ["Random Contrast", "Factor 0.1", "Variabilidad en condiciones de iluminación"],
    ["Random Brightness", "Factor 0.1", "Variabilidad en exposición de luz"]
]

df_augmentation = pd.DataFrame(augmentation_data, columns=["Transformación", "Parámetros", "Objetivo"])

print("\n🔄 Tabla 3: Estrategia de Data Augmentation")
display(df_augmentation)
# Out:
# 🛠️ Tabla 2: Técnicas de Preprocesamiento
#                        Técnica               Configuración  \
# 0  Redimensionamiento (Resize)             224x224 píxeles
# 1             Espacio de Color             RGB (3 canales)
# 2                Normalización      Interna (EfficientNet)
# 3                     Batching        32 imágenes por lote
# 4                  Prefetching  Autotune (Buffer dinámico)
# 5                      Caching               Memoria/Disco
#
#                                        Justificación
# 0                         Estandarización de entrada
# 1                         Formato estándar de imagen
# 2  EfficientNetB0 incluye capa de preprocesamient...
# 3                        Optimización de memoria GPU
# 4                            Carga asíncrona CPU-GPU
# 5              Evita recargar imágenes en cada época
# 🔄 Tabla 3: Estrategia de Data Augmentation
#        Transformación         Parámetros  \
# 0         Random Flip         Horizontal
# 1     Random Rotation  Factor 0.1 (±10%)
# 2         Random Zoom  Factor 0.1 (±10%)
# 3  Random Translation   Height/Width 0.1
# 4     Random Contrast         Factor 0.1
# 5   Random Brightness         Factor 0.1
#
#                                           Objetivo
# 0                Simula espejo (izquierda/derecha)
# 1       Simula variaciones en el ángulo de captura
# 2                    Simula distancia de la cámara
# 3  Simula desplazamiento del objeto en el encuadre
# 4       Variabilidad en condiciones de iluminación
# 5                Variabilidad en exposición de luz

# %% [markdown]
# 5. Definición del modelo VGG19

# %%
from tensorflow.keras.applications import VGG19
from tensorflow.keras.applications.vgg19 import preprocess_input

# 🔹 Capa de preprocesamiento SERIALIZABLE
from tensorflow.keras.applications.vgg19 import preprocess_input
from keras.saving import register_keras_serializable

@register_keras_serializable()
class VGGPreprocess(layers.Layer):
    def call(self, inputs):
        return preprocess_input(inputs)


def build_model(num_classes, input_shape):
    inputs = layers.Input(shape=input_shape)

    # 1️⃣ Data Augmentation
    x = data_augmentation(inputs)

    # 2️⃣ Preprocesamiento correcto para VGG19
    x = VGGPreprocess(name="vgg19_preprocess")(x)

    # 3️⃣ Base VGG19
    base_model = VGG19(
        include_top=False,
        weights="imagenet",
        input_tensor=x
    )

    base_model.trainable = False  # Fase 1

    # 4️⃣ Cabeza personalizada
    x = layers.GlobalAveragePooling2D(name="avg_pool")(base_model.output)
    x = layers.BatchNormalization()(x)
    x = layers.Dense(512, activation='relu')(x)
    x = layers.Dropout(0.5, name="top_dropout")(x)
    outputs = layers.Dense(num_classes, activation='softmax', name="pred")(x)

    model = models.Model(inputs, outputs, name="VGG19_Banana_Classifier")

    return model, base_model

model, base_model = build_model(num_classes, INPUT_SHAPE)
model.summary()
# Out:
# Model: "VGG19_Banana_Classifier"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Data_Augmentation (Sequential)  │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ vgg19_preprocess                │ (None, 224, 224, 3)    │             0 │
# │ (VGGPreprocess)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv4 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv4 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv4 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ avg_pool                        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ top_dropout (Dropout)           │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pred (Dense)                    │ (None, 7)              │         3,591 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,292,679 (77.41 MB)
#  Trainable params: 267,271 (1.02 MB)
#  Non-trainable params: 20,025,408 (76.39 MB)

# %% [markdown]
# 6. Configuración del entrenamiento

# %%
# Tabla de configuración
config_df = pd.DataFrame({
    'Parámetro': ['Optimizer', 'Loss Function', 'Batch Size', 'Img Size', 'Base Trainable (Fase 1)'],
    'Valor': ['Adam', 'Categorical Crossentropy', BATCH_SIZE, IMG_SIZE, 'False']
})
display(config_df)

# Callbacks
callbacks = [
    ModelCheckpoint(BEST_MODEL_PATH, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1),
    EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, min_lr=1e-6, verbose=1)
]

# Compilación Fase 1
model.compile(
    optimizer=optimizers.Adam(learning_rate=1e-3),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
#                  Parámetro                     Valor
# 0                Optimizer                      Adam
# 1            Loss Function  Categorical Crossentropy
# 2               Batch Size                        32
# 3                 Img Size                (224, 224)
# 4  Base Trainable (Fase 1)                     False

# %% [markdown]
# TABLA 4: CONFIGURACIÓN DE HIPERPARÁMETROS

# %%
# ==========================================
# TABLA 4: CONFIGURACIÓN DE HIPERPARÁMETROS
# ==========================================

training_config = [
    ["Arquitectura Base", "VGG19", "Pre-entrenada en ImageNet"],
    ["Pesos Iniciales", "ImageNet", "Transfer Learning"],
    ["Input Shape", f"{INPUT_SHAPE}", "Resolución 224x224x3"],
    ["Optimizador", "Adam", "Algoritmo adaptativo"],
    ["Loss Function", "Categorical Crossentropy", "Clasificación multiclase"],
    ["Learning Rate (Fase 1)", "0.001", "Entrenamiento de la cabeza"],
    ["Learning Rate (Fase 2)", "0.000005", "Fine-Tuning muy estable"],
    ["Dropout", "0.5", "Reducir Overfitting en VGG"],
    ["Base Trainable Fase 1", "False", "Feature Extraction"],
]


df_config = pd.DataFrame(training_config, columns=["Hiperparámetro / Configuración", "Valor", "Descripción"])

print("\n⚙️ Tabla 4: Configuración del Experimento")
display(df_config)
# Out:
# ⚙️ Tabla 4: Configuración del Experimento
#   Hiperparámetro / Configuración                     Valor  \
# 0              Arquitectura Base                     VGG19
# 1                Pesos Iniciales                  ImageNet
# 2                    Input Shape             (224, 224, 3)
# 3                    Optimizador                      Adam
# 4                  Loss Function  Categorical Crossentropy
# 5         Learning Rate (Fase 1)                     0.001
# 6         Learning Rate (Fase 2)                  0.000005
# 7                        Dropout                       0.5
# 8          Base Trainable Fase 1                     False
#
#                   Descripción
# 0   Pre-entrenada en ImageNet
# 1           Transfer Learning
# 2        Resolución 224x224x3
# 3        Algoritmo adaptativo
# 4    Clasificación multiclase
# 5  Entrenamiento de la cabeza
# 6     Fine-Tuning muy estable
# 7  Reducir Overfitting en VGG
# 8          Feature Extraction

# %% [markdown]
# 7. Entrenamiento del modelo

# %%
# --- FASE 1: Feature Extraction ---
print(f"\n🚀 Iniciando Fase 1: Entrenamiento de la cabeza ({NUM_EPOCHS_HEAD} épocas)...")
start_time = time.time()

history_1 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=NUM_EPOCHS_HEAD,
    callbacks=callbacks
)

phase1_time = time.time() - start_time

# --- FASE 2: Fine-Tuning ---
print("\n🔓 Descongelando bloque 5 de VGG19 para Fine-Tuning...")
base_model.trainable = True

for layer in base_model.layers:
    if "block5" in layer.name:
        layer.trainable = True
    else:
        layer.trainable = False

model.compile(
    optimizer=optimizers.Adam(learning_rate=5e-6),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)


print(f"🚀 Iniciando Fase 2: Fine-Tuning ({NUM_EPOCHS_FINE} épocas)...")
start_time_2 = time.time()

# Ajustamos epoch inicial para que la gráfica sea continua
history_2 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=NUM_EPOCHS_HEAD + NUM_EPOCHS_FINE,
    initial_epoch=history_1.epoch[-1] + 1,
    callbacks=callbacks
)

phase2_time = time.time() - start_time_2

# Tabla de tiempos
time_df = pd.DataFrame({
    'Fase': ['Feature Extraction', 'Fine-Tuning', 'Total'],
    'Tiempo (min)': [phase1_time/60, phase2_time/60, (phase1_time+phase2_time)/60]
})
display(time_df)
# Out:
# 🚀 Iniciando Fase 1: Entrenamiento de la cabeza (5 épocas)...
# Epoch 1/5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.6064 - loss: 1.1192
# Epoch 1: val_accuracy improved from -inf to 0.85429, saving model to /content/drive/MyDrive/Entrenamiento con balanceo/VGG19/banano_VGG19_best_scientific.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 23s 191ms/step - accuracy: 0.6075 - loss: 1.1163 - val_accuracy: 0.8543 - val_loss: 0.4183 - learning_rate: 0.0010
# Epoch 2/5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.8704 - loss: 0.3854
# Epoch 2: val_accuracy improved from 0.85429 to 0.94000, saving model to /content/drive/MyDrive/Entrenamiento con balanceo/VGG19/banano_VGG19_best_scientific.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 21s 187ms/step - accuracy: 0.8704 - loss: 0.3853 - val_accuracy: 0.9400 - val_loss: 0.2072 - learning_rate: 0.0010
# Epoch 3/5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9057 - loss: 0.2688
# Epoch 3: val_accuracy improved from 0.94000 to 0.95143, saving model to /content/drive/MyDrive/Entrenamiento con balanceo/VGG19/banano_VGG19_best_scientific.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 20s 182ms/step - accuracy: 0.9057 - loss: 0.2687 - val_accuracy: 0.9514 - val_loss: 0.1644 - learning_rate: 0.0010
# Epoch 4/5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9236 - loss: 0.2218
# Epoch 4: val_accuracy improved from 0.95143 to 0.96286, saving model to /content/drive/MyDrive/Entrenamiento con balanceo/VGG19/banano_VGG19_best_scientific.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 20s 183ms/step - accuracy: 0.9236 - loss: 0.2218 - val_accuracy: 0.9629 - val_loss: 0.1242 - learning_rate: 0.0010
# Epoch 5/5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9330 - loss: 0.1920
# Epoch 5: val_accuracy did not improve from 0.96286
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 20s 178ms/step - accuracy: 0.9331 - loss: 0.1919 - val_accuracy: 0.9629 - val_loss: 0.1092 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 4.
#
# 🔓 Descongelando bloque 5 de VGG19 para Fine-Tuning...
# 🚀 Iniciando Fase 2: Fine-Tuning (15 épocas)...
# Epoch 6/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9499 - loss: 0.1421
# Epoch 6: val_accuracy improved from 0.96286 to 0.98000, saving model to /content/drive/MyDrive/Entrenamiento con balanceo/VGG19/banano_VGG19_best_scientific.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 29s 236ms/step - accuracy: 0.9499 - loss: 0.1420 - val_accuracy: 0.9800 - val_loss: 0.0736 - learning_rate: 5.0000e-06
# Epoch 7/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9648 - loss: 0.1002
# Epoch 7: val_accuracy improved from 0.98000 to 0.98571, saving model to /content/drive/MyDrive/Entrenamiento con balanceo/VGG19/banano_VGG19_best_scientific.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 26s 232ms/step - accuracy: 0.9648 - loss: 0.1002 - val_accuracy: 0.9857 - val_loss: 0.0492 - learning_rate: 5.0000e-06
# Epoch 8/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9689 - loss: 0.0869
# Epoch 8: val_accuracy did not improve from 0.98571
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 25s 224ms/step - accuracy: 0.9689 - loss: 0.0869 - val_accuracy: 0.9857 - val_loss: 0.0493 - learning_rate: 5.0000e-06
# Epoch 9/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9804 - loss: 0.0705
# Epoch 9: val_accuracy improved from 0.98571 to 0.98857, saving model to /content/drive/MyDrive/Entrenamiento con balanceo/VGG19/banano_VGG19_best_scientific.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 25s 231ms/step - accuracy: 0.9804 - loss: 0.0705 - val_accuracy: 0.9886 - val_loss: 0.0375 - learning_rate: 5.0000e-06
# Epoch 10/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9809 - loss: 0.0671
# Epoch 10: val_accuracy did not improve from 0.98857
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 25s 224ms/step - accuracy: 0.9809 - loss: 0.0671 - val_accuracy: 0.9886 - val_loss: 0.0326 - learning_rate: 5.0000e-06
# Epoch 11/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9808 - loss: 0.0589
# Epoch 11: val_accuracy improved from 0.98857 to 0.99143, saving model to /content/drive/MyDrive/Entrenamiento con balanceo/VGG19/banano_VGG19_best_scientific.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 25s 231ms/step - accuracy: 0.9808 - loss: 0.0589 - val_accuracy: 0.9914 - val_loss: 0.0334 - learning_rate: 5.0000e-06
# Epoch 12/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9861 - loss: 0.0541
# Epoch 12: val_accuracy improved from 0.99143 to 0.99429, saving model to /content/drive/MyDrive/Entrenamiento con balanceo/VGG19/banano_VGG19_best_scientific.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 26s 233ms/step - accuracy: 0.9861 - loss: 0.0541 - val_accuracy: 0.9943 - val_loss: 0.0225 - learning_rate: 5.0000e-06
# Epoch 13/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9823 - loss: 0.0554
# Epoch 13: val_accuracy improved from 0.99429 to 0.99714, saving model to /content/drive/MyDrive/Entrenamiento con balanceo/VGG19/banano_VGG19_best_scientific.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 26s 239ms/step - accuracy: 0.9823 - loss: 0.0554 - val_accuracy: 0.9971 - val_loss: 0.0166 - learning_rate: 5.0000e-06
# Epoch 14/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9838 - loss: 0.0440
# Epoch 14: val_accuracy did not improve from 0.99714
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 25s 223ms/step - accuracy: 0.9838 - loss: 0.0440 - val_accuracy: 0.9971 - val_loss: 0.0190 - learning_rate: 5.0000e-06
# Epoch 15/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9843 - loss: 0.0496
# Epoch 15: val_accuracy did not improve from 0.99714
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - accuracy: 0.9843 - loss: 0.0496 - val_accuracy: 0.9943 - val_loss: 0.0154 - learning_rate: 5.0000e-06
# Epoch 16/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9900 - loss: 0.0351
# Epoch 16: val_accuracy did not improve from 0.99714
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - accuracy: 0.9900 - loss: 0.0351 - val_accuracy: 0.9943 - val_loss: 0.0150 - learning_rate: 5.0000e-06
# Epoch 17/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9942 - loss: 0.0262
# Epoch 17: val_accuracy did not improve from 0.99714
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 24s 222ms/step - accuracy: 0.9942 - loss: 0.0262 - val_accuracy: 0.9943 - val_loss: 0.0154 - learning_rate: 5.0000e-06
# Epoch 18/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9925 - loss: 0.0298
# Epoch 18: val_accuracy did not improve from 0.99714
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - accuracy: 0.9926 - loss: 0.0298 - val_accuracy: 0.9971 - val_loss: 0.0115 - learning_rate: 5.0000e-06
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 13.
#                  Fase  Tiempo (min)
# 0  Feature Extraction      1.728885
# 1         Fine-Tuning      5.482202
# 2               Total      7.211087

# %% [markdown]
# 8. Curvas de aprendizaje

# %%
def plot_training_history(h1, h2):
    acc = h1.history['accuracy'] + h2.history['accuracy']
    val_acc = h1.history['val_accuracy'] + h2.history['val_accuracy']
    loss = h1.history['loss'] + h2.history['loss']
    val_loss = h1.history['val_loss'] + h2.history['val_loss']

    epochs_range = range(len(acc))

    plt.figure(figsize=(14, 6))

    # Accuracy
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.axvline(x=len(h1.history['accuracy'])-1, color='green', linestyle='--', label='Inicio Fine-Tuning')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.grid(True)

    # Loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.axvline(x=len(h1.history['loss'])-1, color='green', linestyle='--', label='Inicio Fine-Tuning')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.grid(True)

    plt.show()

plot_training_history(history_1, history_2)

# %% [markdown]
# 9. Evaluación del modelo (Cálculo de métricas detalladas)

# %%
print("\n🧪 Evaluando modelo en Test Set...")

# Obtener etiquetas verdaderas y predicciones
y_true = []
y_pred_probs = []

# Iterar sobre el dataset de test (sin shuffle)
for images, labels in test_ds:
    y_true.extend(np.argmax(labels.numpy(), axis=1))
    preds = model.predict(images, verbose=0)
    y_pred_probs.extend(preds)

y_true = np.array(y_true)
y_pred_probs = np.array(y_pred_probs)
y_pred = np.argmax(y_pred_probs, axis=1)

# Cálculo de métricas One-vs-All por clase
metrics_list = []

for i, class_name in enumerate(class_names):
    # Crear etiquetas binarias para la clase actual vs resto
    y_true_cls = (y_true == i).astype(int)
    y_pred_cls = (y_pred == i).astype(int)

    # Matriz de confusión binaria
    tn, fp, fn, tp = confusion_matrix(y_true_cls, y_pred_cls).ravel()

    # Métricas
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    precision = tp / (tp + fp) if (tp + fp) > 0 else 0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0  # Sensitivity / TPR
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0 # TNR
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
    fpr = fp / (tn + fp) if (tn + fp) > 0 else 0
    youden = recall + specificity - 1

    # AUC One-vs-Rest
    try:
        auc = roc_auc_score(y_true_cls, y_pred_probs[:, i])
    except ValueError:
        auc = 0.0

    support = tp + fn

    metrics_list.append({
        'Class': class_name,
        'Accuracy': accuracy,
        'Precision': precision,
        'Recall (Sens)': recall,
        'Specificity': specificity,
        'F1-Score': f1,
        'AUC': auc,
        'Youden Index': youden,
        'FPR': fpr,
        'TP': tp, 'TN': tn, 'FP': fp, 'FN': fn,
        'Support': support
    })

metrics_df = pd.DataFrame(metrics_list)
# Out:
# 🧪 Evaluando modelo en Test Set...

# %% [markdown]
# 10. Matriz de Confusión

# %%
wawewecm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.ylabel('Etiqueta Verdadera')
plt.xlabel('Etiqueta Predicha')
plt.title('Matriz de Confusión - VGG19v')
plt.show()

# %% [markdown]
# 11. Tablas de métricas

# %%
# 11.1 Tabla por Clase
print("\n📊 Métricas Detalladas por Clase:")
display(metrics_df.round(4))

# 11.2 Métricas Globales (Weighted Average)
global_metrics = {
    'Global Accuracy': accuracy_score(y_true, y_pred),
    'Weighted Precision': precision_score(y_true, y_pred, average='weighted'),
    'Weighted Recall': recall_score(y_true, y_pred, average='weighted'),
    'Weighted F1': f1_score(y_true, y_pred, average='weighted'),
    'Macro Recall': recall_score(y_true, y_pred, average='macro'),
    'Macro AUC': roc_auc_score(y_true, y_pred_probs, multi_class='ovr', average='macro')
}

global_df = pd.DataFrame([global_metrics])
print("\n🌍 Métricas Globales:")
display(global_df.round(4))
# Out:
# 📊 Métricas Detalladas por Clase:
#                 Class  Accuracy  Precision  Recall (Sens)  Specificity  \
# 0                apto    1.0000     1.0000           1.00       1.0000
# 1     cascara_partida    0.9971     0.9804           1.00       0.9967
# 2      cicatriz_golpe    0.9886     0.9792           0.94       0.9967
# 3     corte_cuchareta    1.0000     1.0000           1.00       1.0000
# 4     mal_formaciones    0.9943     0.9800           0.98       0.9967
# 5       marca_madurez    0.9971     0.9804           1.00       0.9967
# 6  plaga_enfermedades    1.0000     1.0000           1.00       1.0000
#
#    F1-Score     AUC  Youden Index     FPR  TP   TN  FP  FN  Support
# 0    1.0000  1.0000        1.0000  0.0000  50  300   0   0       50
# 1    0.9901  1.0000        0.9967  0.0033  50  299   1   0       50
# 2    0.9592  0.9997        0.9367  0.0033  47  299   1   3       50
# 3    1.0000  1.0000        1.0000  0.0000  50  300   0   0       50
# 4    0.9800  0.9999        0.9767  0.0033  49  299   1   1       50
# 5    0.9901  1.0000        0.9967  0.0033  50  299   1   0       50
# 6    1.0000  1.0000        1.0000  0.0000  50  300   0   0       50
# 🌍 Métricas Globales:
#    Global Accuracy  Weighted Precision  Weighted Recall  Weighted F1  \
# 0           0.9886              0.9886           0.9886       0.9885
#
#    Macro Recall  Macro AUC
# 0        0.9886        1.0

# %% [markdown]
# 12. Evaluación del mejor modelo

# %%
print(f"\n🏆 Cargando el mejor modelo guardado desde: {BEST_MODEL_PATH}")
try:
    best_model = tf.keras.models.load_model(BEST_MODEL_PATH)

    # Evaluación rápida del mejor modelo
    loss, acc = best_model.evaluate(test_ds, verbose=0)
    print(f"Best Model Test Accuracy: {acc:.4f}")
    print(f"Best Model Test Loss: {loss:.4f}")

    # Comprobación de selección
    if acc > global_metrics['Global Accuracy']:
        print("✅ El modelo guardado es mejor que el modelo final en memoria.")
    else:
        print("ℹ️ El modelo en memoria tiene un rendimiento similar o igual.")

except Exception as e:
    print(f"Error cargando el modelo: {e}")
# Out:
# 🏆 Cargando el mejor modelo guardado desde: /content/drive/MyDrive/Entrenamiento con balanceo/VGG19/banano_VGG19_best_scientific.keras
# Best Model Test Accuracy: 0.9886
# Best Model Test Loss: 0.0204
# ℹ️ El modelo en memoria tiene un rendimiento similar o igual.

# %% [markdown]
# 13. Resultados finales y Conclusiones

# %%
# Generar reporte de texto estándar de scikit-learn para complementar
print("\n📝 Classification Report (Scikit-Learn Standard):")
print(classification_report(y_true, y_pred, target_names=class_names))

# Análisis de resultados (Markdown generado dinámicamente)
best_class = metrics_df.loc[metrics_df['F1-Score'].idxmax()]
worst_class = metrics_df.loc[metrics_df['F1-Score'].idxmin()]

print("="*50)
print("CONCLUSIONES DEL EXPERIMENTO")
print("="*50)
print(f"1. Rendimiento Global: El modelo alcanzó una exactitud (Top-1 Accuracy) del {global_metrics['Global Accuracy']:.2%}.")
print(f"2. Mejor Clase: '{best_class['Class']}' con un F1-Score de {best_class['F1-Score']:.4f}.")
print(f"3. Peor Clase: '{worst_class['Class']}' con un F1-Score de {worst_class['F1-Score']:.4f}. (Posible confusión visual).")
print(f"4. Discriminación: El AUC promedio es {global_metrics['Macro AUC']:.4f}, indicando una { 'excelente' if global_metrics['Macro AUC'] > 0.9 else 'buena' } capacidad de separación entre clases.")
print(f"5. Tiempos: El entrenamiento total tomó aproximadamente {(phase1_time+phase2_time)/60:.1f} minutos.")
print("="*50)
# Out:
# 📝 Classification Report (Scikit-Learn Standard):
#                     precision    recall  f1-score   support
#
#               apto       1.00      1.00      1.00        50
#    cascara_partida       0.98      1.00      0.99        50
#     cicatriz_golpe       0.98      0.94      0.96        50
#    corte_cuchareta       1.00      1.00      1.00        50
#    mal_formaciones       0.98      0.98      0.98        50
#      marca_madurez       0.98      1.00      0.99        50
# plaga_enfermedades       1.00      1.00      1.00        50
#
#           accuracy                           0.99       350
#          macro avg       0.99      0.99      0.99       350
#       weighted avg       0.99      0.99      0.99       350
#
# ==================================================
# CONCLUSIONES DEL EXPERIMENTO
# ==================================================
# 1. Rendimiento Global: El modelo alcanzó una exactitud (Top-1 Accuracy) del 98.86%.
# 2. Mejor Clase: 'apto' con un F1-Score de 1.0000.
# 3. Peor Clase: 'cicatriz_golpe' con un F1-Score de 0.9592. (Posible confusión visual).
# 4. Discriminación: El AUC promedio es 1.0000, indicando una excelente capacidad de separación entre clases.
# 5. Tiempos: El entrenamiento total tomó aproximadamente 7.2 minutos.
# ==================================================

# %% [markdown]
# 14. EXPORTACIÓN DEL MODELO Y ETIQUETAS (DEPLOYMENT)

# %%
import tensorflow as tf
import os

# =========================================================
# 14. EXPORTACIÓN DEL MODELO Y ETIQUETAS 
# =========================================================

print(f"\n📲 Preparando archivos para despliegue en móvil...")

# ---------------------------------------------------------
# PASO 1: Convertir el modelo .keras a .tflite
# ---------------------------------------------------------
print("1️⃣  Cargando el mejor modelo guardado (.keras)...")
if not os.path.exists(BEST_MODEL_PATH):
    raise FileNotFoundError(f"❌ No se encontró el modelo en: {BEST_MODEL_PATH}")

model = tf.keras.models.load_model(BEST_MODEL_PATH)

print("2️⃣  Configurando el convertidor TFLite...")
converter = tf.lite.TFLiteConverter.from_keras_model(model)

converter.optimizations = [tf.lite.Optimize.DEFAULT]

print("3️⃣  Convirtiendo modelo (esto puede tardar unos segundos)...")
tflite_model = converter.convert()

# Definir ruta de salida
tflite_filename = "banano_VGG19.tflite"
tflite_path = os.path.join(MODELS_DIR, tflite_filename)

# Guardar el archivo binario
with open(tflite_path, 'wb') as f:
    f.write(tflite_model)

print(f"✅ Modelo TFLite exportado exitosamente: {tflite_path}")

# ---------------------------------------------------------
# PASO 2: Guardar etiquetas (Labels)
# ---------------------------------------------------------
print("4️⃣  Generando archivo de etiquetas (labels.txt)...")
labels_path = os.path.join(MODELS_DIR, "labels.txt")

with open(labels_path, 'w') as f:
    for name in class_names:
        f.write(name + '\n')

print(f"✅ Etiquetas guardadas en: {labels_path}")

# ---------------------------------------------------------
# Verificación final para el desarrollador
# ---------------------------------------------------------
print("\n" + "="*50)
print("📌 INSTRUCCIONES PARA FLUTTER")
print("="*50)
print("1. Copia el archivo .tflite y labels.txt a la carpeta 'assets/' de tu proyecto Flutter.")
print("2. Asegúrate de que el orden de las clases sea EXACTAMENTE este:")
print("-" * 20)
for i, name in enumerate(class_names):
    print(f"[{i}] -> {name}")
print("-" * 20)
# Out:
# 📲 Preparando archivos para despliegue en móvil...
# 1️⃣  Cargando el mejor modelo guardado (.keras)...
# 2️⃣  Configurando el convertidor TFLite...
# 3️⃣  Convirtiendo modelo (esto puede tardar unos segundos)...
# Saved artifact at '/tmp/tmpmutenzbq'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer_2')
# Output Type:
#   TensorSpec(shape=(None, 7), dtype=tf.float32, name=None)
# Captures:
#   132498584045328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132498584046672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132498584047632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132498584046864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132498584048016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132498584047824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132498584048400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132498584048208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132498584048784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132498584048592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132498584049168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132498584048976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132498584049552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132498584049360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132498584049936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132498584049744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132498584050320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132498584050128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132498584050704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132498584050512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132498584051088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132498584050896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132498584051472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132498584051280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132498584051856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132498584051664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132498584052240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132498584052048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132498584052624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132498584052432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132498584053008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132498584052816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132498584047440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132498584053776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132498584053584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132498584046480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132499342191568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132498584053200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132498584047248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132498584054160: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ✅ Modelo TFLite exportado exitosamente: /content/drive/MyDrive/Entrenamiento con balanceo/VGG19/banano_VGG19.tflite
# 4️⃣  Generando archivo de etiquetas (labels.txt)...
# ✅ Etiquetas guardadas en: /content/drive/MyDrive/Entrenamiento con balanceo/VGG19/labels.txt
#
# ==================================================
# 📌 INSTRUCCIONES PARA FLUTTER
# ==================================================
# 1. Copia el archivo .tflite y labels.txt a la carpeta 'assets/' de tu proyecto Flutter.
# 2. Asegúrate de que el orden de las clases sea EXACTAMENTE este:
# --------------------
# [0] -> apto
# [1] -> cascara_partida
# [2] -> cicatriz_golpe
# [3] -> corte_cuchareta
# [4] -> mal_formaciones
# [5] -> marca_madurez
# [6] -> plaga_enfermedades
# --------------------

# %% [markdown]
# 15. Análisis de Optimización: Comparativa de Pesos

# %%
import matplotlib.pyplot as plt
import os

# Configuración de rutas para guardar la gráfica
img_save_path = "/content/drive/MyDrive/Entrenamiento con balanceo/VGG19"
os.makedirs(img_save_path, exist_ok=True)

# Obtener tamaños de archivo en MB
keras_size = os.path.getsize(BEST_MODEL_PATH) / (1024 * 1024)
tflite_size = os.path.getsize(tflite_path) / (1024 * 1024)

# Datos para el gráfico
models_comparison = ['Keras (.keras)', 'TFLite (.tflite)']
sizes = [keras_size, tflite_size]
colors = ['#1f77b4', '#2ca02c'] 

# ===== Gráfico de comparación de tamaños =====
plt.figure(figsize=(8, 6))
bars = plt.bar(models_comparison, sizes, color=colors, width=0.5)

plt.ylabel('Tamaño en MB', fontsize=12)
plt.title(f'Optimización de Modelo: VGG19\nReducción: {100 * (1 - tflite_size/keras_size):.1f}%', fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Añadir etiquetas de valor sobre las barras
for bar in bars:
    yval = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        yval + 0.2,
        f'{yval:.2f} MB',
        ha='center',
        va='bottom',
        fontsize=12,
        fontweight='bold'
    )

plt.tight_layout()

# Guardar la gráfica
output_chart_path = os.path.join(img_save_path, "model_size_comparison_VGG19.png")
plt.savefig(output_chart_path, dpi=300, bbox_inches='tight')

print(f"📊 Gráfico de comparación guardado en: {output_chart_path}")
plt.show()
# Out:
# 📊 Gráfico de comparación guardado en: /content/drive/MyDrive/Entrenamiento con balanceo/VGG19/model_size_comparison_VGG19.png
