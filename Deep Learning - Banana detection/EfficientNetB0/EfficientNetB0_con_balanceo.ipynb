# %% [markdown]
# 1. Importación de librerías

# %%
import os
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import (confusion_matrix, classification_report, accuracy_score,
                             precision_score, recall_score, f1_score, roc_auc_score)
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Ignorar warnings para limpieza del output
import warnings
warnings.filterwarnings('ignore')

print(f"TensorFlow Version: {tf.__version__}")
print(f"NumPy Version: {np.__version__}")
# Out:
# TensorFlow Version: 2.19.0
# NumPy Version: 2.0.2

# %% [markdown]
# 2. Configuración del entorno

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Semillas para reproducibilidad
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)

# Configuración de GPU
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"✅ GPU detectada: {len(gpus)} disponible(s)")
    except RuntimeError as e:
        print(e)
else:
    print("⚠️ No se detectó GPU. El entrenamiento será lento.")

# Parámetros Globales
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
CHANNELS = 3
INPUT_SHAPE = IMG_SIZE + (CHANNELS,)
NUM_EPOCHS_HEAD = 5    # Épocas fase 1 (cabeza)
NUM_EPOCHS_FINE = 15   # Épocas fase 2 (fine-tuning)

BASE_DIR = "/content/drive/MyDrive/Dataset" 
TRAIN_DIR = os.path.join(BASE_DIR, "Train")
VAL_DIR   = os.path.join(BASE_DIR, "Validation")
TEST_DIR  = os.path.join(BASE_DIR, "Test")
MODELS_DIR = "/content/drive/MyDrive/Entrenamiento con balanceo/EfficientNetB0"
os.makedirs(MODELS_DIR, exist_ok=True)
BEST_MODEL_PATH = os.path.join(MODELS_DIR, "banano_efficientnetb0_best_scientific.keras")
# Out:
# ✅ GPU detectada: 1 disponible(s)

# %% [markdown]
# 3. Carga y exploración del dataset

# %%
# Carga de datasets usando image_dataset_from_directory
train_ds = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR,
    labels='inferred',
    label_mode='categorical',
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=SEED
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    VAL_DIR,
    labels='inferred',
    label_mode='categorical',
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False,
    seed=SEED
)

test_ds = tf.keras.utils.image_dataset_from_directory(
    TEST_DIR,
    labels='inferred',
    label_mode='categorical',
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False,
    seed=SEED
)

class_names = train_ds.class_names
num_classes = len(class_names)

print(f"\n🏷️ Clases detectadas ({num_classes}): {class_names}")

# Tabla de Support (Conteo de muestras)
def count_samples(directory, class_names):
    counts = []
    for cls in class_names:
        path = os.path.join(directory, cls)
        if os.path.exists(path):
            counts.append(len(os.listdir(path)))
        else:
            counts.append(0)
    return counts

train_counts = count_samples(TRAIN_DIR, class_names)
val_counts = count_samples(VAL_DIR, class_names)
test_counts = count_samples(TEST_DIR, class_names)

df_support = pd.DataFrame({
    'Clase': class_names,
    'Train Samples': train_counts,
    'Validation Samples': val_counts,
    'Test Samples': test_counts
})

# Gráfico de distribución
plt.figure(figsize=(12, 5))
x = np.arange(len(class_names))
width = 0.25
plt.bar(x - width, train_counts, width, label='Train', color='#1f77b4')
plt.bar(x, val_counts, width, label='Validation', color='#ff7f0e')
plt.bar(x + width, test_counts, width, label='Test', color='#2ca02c')
plt.xticks(x, class_names, rotation=45)
plt.ylabel('Número de imágenes')
plt.title('Distribución de Muestras por Clase')
plt.legend()
plt.tight_layout()
plt.show()

display(df_support)
# Out:
# Found 3500 files belonging to 7 classes.
# Found 350 files belonging to 7 classes.
# Found 350 files belonging to 7 classes.
#
# 🏷️ Clases detectadas (7): ['apto', 'cascara_partida', 'cicatriz_golpe', 'corte_cuchareta', 'mal_formaciones', 'marca_madurez', 'plaga_enfermedades']
#                 Clase  Train Samples  Validation Samples  Test Samples
# 0                apto            500                  50            50
# 1     cascara_partida            500                  50            50
# 2      cicatriz_golpe            500                  50            50
# 3     corte_cuchareta            500                  50            50
# 4     mal_formaciones            500                  50            50
# 5       marca_madurez            500                  50            50
# 6  plaga_enfermedades            500                  50            50

# %% [markdown]
# TABLA 1: DISTRIBUCIÓN POR CLASES DETALLADA

# %%
# ==========================================
# TABLA 1: DISTRIBUCIÓN POR CLASES DETALLADA
# ==========================================

# Calcular totales por clase
total_per_class = [t + v + te for t, v, te in zip(train_counts, val_counts, test_counts)]
total_dataset = sum(total_per_class)

# Calcular porcentajes
percentages = [f"{(count/total_dataset)*100:.2f}%" for count in total_per_class]

df_distribution = pd.DataFrame({
    'Clase (Etiqueta)': class_names,
    'Entrenamiento (Train)': train_counts,
    'Validación (Val)': val_counts,
    'Prueba (Test)': test_counts,
    'Total Muestras': total_per_class,
    'Distribución (%)': percentages
})

# Añadir fila de totales
row_total = pd.DataFrame({
    'Clase (Etiqueta)': ['TOTAL'],
    'Entrenamiento (Train)': [sum(train_counts)],
    'Validación (Val)': [sum(val_counts)],
    'Prueba (Test)': [sum(test_counts)],
    'Total Muestras': [total_dataset],
    'Distribución (%)': ['100%']
})

df_distribution = pd.concat([df_distribution, row_total], ignore_index=True)

print("\n📋 Tabla 1: Distribución del Dataset por Clases")
display(df_distribution)
# Out:
# 📋 Tabla 1: Distribución del Dataset por Clases
#      Clase (Etiqueta)  Entrenamiento (Train)  Validación (Val)  Prueba (Test)  \
# 0                apto                    500                50             50
# 1     cascara_partida                    500                50             50
# 2      cicatriz_golpe                    500                50             50
# 3     corte_cuchareta                    500                50             50
# 4     mal_formaciones                    500                50             50
# 5       marca_madurez                    500                50             50
# 6  plaga_enfermedades                    500                50             50
# 7               TOTAL                   3500               350            350
#
#    Total Muestras Distribución (%)
# 0             600           14.29%
# 1             600           14.29%
# 2             600           14.29%
# 3             600           14.29%
# 4             600           14.29%
# 5             600           14.29%
# 6             600           14.29%
# 7            4200             100%

# %% [markdown]
# 4. Preprocesamiento de datos

# %%
# Optimización de carga (Prefetching)
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)

# Capa de Data Augmentation dentro del modelo (GPU acelerada)
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
    layers.RandomTranslation(0.1, 0.1),
    layers.RandomContrast(0.1),
    layers.RandomBrightness(0.1)
], name="Data_Augmentation")

print("✅ Pipeline de datos configurado.")
# Out:
# ✅ Pipeline de datos configurado.

# %%
# ==================================================
# TABLA 2: TÉCNICAS DE PREPROCESAMIENTO APLICADAS
# ==================================================
preprocessing_data = [
    ["Redimensionamiento (Resize)", f"{IMG_SIZE[0]}x{IMG_SIZE[1]} píxeles", "Estandarización de entrada"],
    ["Espacio de Color", "RGB (3 canales)", "Formato estándar de imagen"],
    ["Normalización", "Interna (EfficientNet)", "EfficientNetB0 incluye capa de preprocesamiento (espera rangos [0-255])"],
    ["Batching", f"{BATCH_SIZE} imágenes por lote", "Optimización de memoria GPU"],
    ["Prefetching", "Autotune (Buffer dinámico)", "Carga asíncrona CPU-GPU"],
    ["Caching", "Memoria/Disco", "Evita recargar imágenes en cada época"]
]

df_preprocessing = pd.DataFrame(preprocessing_data, columns=["Técnica", "Configuración", "Justificación"])

print("\n🛠️ Tabla 2: Técnicas de Preprocesamiento")
display(df_preprocessing)


# ==================================================
# TABLA 3: TÉCNICAS DE AUMENTO DE DATOS (DATA AUGMENTATION)
# ==================================================
augmentation_data = [
    ["Random Flip", "Horizontal", "Simula espejo (izquierda/derecha)"],
    ["Random Rotation", "Factor 0.1 (±10%)", "Simula variaciones en el ángulo de captura"],
    ["Random Zoom", "Factor 0.1 (±10%)", "Simula distancia de la cámara"],
    ["Random Translation", "Height/Width 0.1", "Simula desplazamiento del objeto en el encuadre"],
    ["Random Contrast", "Factor 0.1", "Variabilidad en condiciones de iluminación"],
    ["Random Brightness", "Factor 0.1", "Variabilidad en exposición de luz"]
]

df_augmentation = pd.DataFrame(augmentation_data, columns=["Transformación", "Parámetros", "Objetivo"])

print("\n🔄 Tabla 3: Estrategia de Data Augmentation")
display(df_augmentation)
# Out:
# 🛠️ Tabla 2: Técnicas de Preprocesamiento
#                        Técnica               Configuración  \
# 0  Redimensionamiento (Resize)             224x224 píxeles
# 1             Espacio de Color             RGB (3 canales)
# 2                Normalización      Interna (EfficientNet)
# 3                     Batching        32 imágenes por lote
# 4                  Prefetching  Autotune (Buffer dinámico)
# 5                      Caching               Memoria/Disco
#
#                                        Justificación
# 0                         Estandarización de entrada
# 1                         Formato estándar de imagen
# 2  EfficientNetB0 incluye capa de preprocesamient...
# 3                        Optimización de memoria GPU
# 4                            Carga asíncrona CPU-GPU
# 5              Evita recargar imágenes en cada época
# 🔄 Tabla 3: Estrategia de Data Augmentation
#        Transformación         Parámetros  \
# 0         Random Flip         Horizontal
# 1     Random Rotation  Factor 0.1 (±10%)
# 2         Random Zoom  Factor 0.1 (±10%)
# 3  Random Translation   Height/Width 0.1
# 4     Random Contrast         Factor 0.1
# 5   Random Brightness         Factor 0.1
#
#                                           Objetivo
# 0                Simula espejo (izquierda/derecha)
# 1       Simula variaciones en el ángulo de captura
# 2                    Simula distancia de la cámara
# 3  Simula desplazamiento del objeto en el encuadre
# 4       Variabilidad en condiciones de iluminación
# 5                Variabilidad en exposición de luz

# %% [markdown]
# 5. Definición del modelo EfficientNetB0

# %%
def build_model(num_classes, input_shape):
    inputs = layers.Input(shape=input_shape)

    # 1. Data Augmentation
    x = data_augmentation(inputs)

    # 2. EfficientNetB0 Base (Pre-entrenado)
    # Nota: EfficientNet incluye normalización interna, no hace falta Rescaling manual previo
    base_model = tf.keras.applications.EfficientNetB0(
        include_top=False,
        weights="imagenet",
        input_tensor=x
    )

    # Congelamos la base inicialmente
    base_model.trainable = False

    # 3. Reconstrucción de la arquitectura
    # Usamos output del base_model.output porque input_tensor ya está conectado
    x = layers.GlobalAveragePooling2D(name="avg_pool")(base_model.output)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.3, name="top_dropout")(x)

    # 4. Capa de salida
    outputs = layers.Dense(num_classes, activation="softmax", name="pred")(x)

    model = models.Model(inputs, outputs, name="EfficientNetB0_Banana_Classifier")
    return model, base_model

model, base_model = build_model(num_classes, INPUT_SHAPE)
model.summary()

# Visualización de la arquitectura (requiere pydot y graphviz)
# tf.keras.utils.plot_model(model, show_shapes=True, show_layer_names=True)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "EfficientNetB0_Banana_Classifier"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Data_Augmentation   │ (None, 224, 224,  │          0 │ input_layer[0][0] │
# │ (Sequential)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling           │ (None, 224, 224,  │          0 │ Data_Augmentatio… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normalization       │ (None, 224, 224,  │          7 │ rescaling[0][0]   │
# │ (Normalization)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling_1         │ (None, 224, 224,  │          0 │ normalization[0]… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv_pad       │ (None, 225, 225,  │          0 │ rescaling_1[0][0] │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv (Conv2D)  │ (None, 112, 112,  │        864 │ stem_conv_pad[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_bn             │ (None, 112, 112,  │        128 │ stem_conv[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_activation     │ (None, 112, 112,  │          0 │ stem_bn[0][0]     │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_dwconv      │ (None, 112, 112,  │        288 │ stem_activation[… │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_bn          │ (None, 112, 112,  │        128 │ block1a_dwconv[0… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_activation  │ (None, 112, 112,  │          0 │ block1a_bn[0][0]  │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_squeeze  │ (None, 32)        │          0 │ block1a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_reshape  │ (None, 1, 1, 32)  │          0 │ block1a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_reduce   │ (None, 1, 1, 8)   │        264 │ block1a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_expand   │ (None, 1, 1, 32)  │        288 │ block1a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_excite   │ (None, 112, 112,  │          0 │ block1a_activati… │
# │ (Multiply)          │ 32)               │            │ block1a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_project_co… │ (None, 112, 112,  │        512 │ block1a_se_excit… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_project_bn  │ (None, 112, 112,  │         64 │ block1a_project_… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_conv │ (None, 112, 112,  │      1,536 │ block1a_project_… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_bn   │ (None, 112, 112,  │        384 │ block2a_expand_c… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_act… │ (None, 112, 112,  │          0 │ block2a_expand_b… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_dwconv_pad  │ (None, 113, 113,  │          0 │ block2a_expand_a… │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_dwconv      │ (None, 56, 56,    │        864 │ block2a_dwconv_p… │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_bn          │ (None, 56, 56,    │        384 │ block2a_dwconv[0… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_activation  │ (None, 56, 56,    │          0 │ block2a_bn[0][0]  │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_squeeze  │ (None, 96)        │          0 │ block2a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_reshape  │ (None, 1, 1, 96)  │          0 │ block2a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_reduce   │ (None, 1, 1, 4)   │        388 │ block2a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_expand   │ (None, 1, 1, 96)  │        480 │ block2a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_excite   │ (None, 56, 56,    │          0 │ block2a_activati… │
# │ (Multiply)          │ 96)               │            │ block2a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_project_co… │ (None, 56, 56,    │      2,304 │ block2a_se_excit… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_project_bn  │ (None, 56, 56,    │         96 │ block2a_project_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_conv │ (None, 56, 56,    │      3,456 │ block2a_project_… │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_bn   │ (None, 56, 56,    │        576 │ block2b_expand_c… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_act… │ (None, 56, 56,    │          0 │ block2b_expand_b… │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_dwconv      │ (None, 56, 56,    │      1,296 │ block2b_expand_a… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_bn          │ (None, 56, 56,    │        576 │ block2b_dwconv[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_activation  │ (None, 56, 56,    │          0 │ block2b_bn[0][0]  │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_squeeze  │ (None, 144)       │          0 │ block2b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_reshape  │ (None, 1, 1, 144) │          0 │ block2b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_reduce   │ (None, 1, 1, 6)   │        870 │ block2b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_expand   │ (None, 1, 1, 144) │      1,008 │ block2b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_excite   │ (None, 56, 56,    │          0 │ block2b_activati… │
# │ (Multiply)          │ 144)              │            │ block2b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_project_co… │ (None, 56, 56,    │      3,456 │ block2b_se_excit… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_project_bn  │ (None, 56, 56,    │         96 │ block2b_project_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_drop        │ (None, 56, 56,    │          0 │ block2b_project_… │
# │ (Dropout)           │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_add (Add)   │ (None, 56, 56,    │          0 │ block2b_drop[0][… │
# │                     │ 24)               │            │ block2a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_conv │ (None, 56, 56,    │      3,456 │ block2b_add[0][0] │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_bn   │ (None, 56, 56,    │        576 │ block3a_expand_c… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_act… │ (None, 56, 56,    │          0 │ block3a_expand_b… │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_dwconv_pad  │ (None, 59, 59,    │          0 │ block3a_expand_a… │
# │ (ZeroPadding2D)     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_dwconv      │ (None, 28, 28,    │      3,600 │ block3a_dwconv_p… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_bn          │ (None, 28, 28,    │        576 │ block3a_dwconv[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_activation  │ (None, 28, 28,    │          0 │ block3a_bn[0][0]  │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_squeeze  │ (None, 144)       │          0 │ block3a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_reshape  │ (None, 1, 1, 144) │          0 │ block3a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_reduce   │ (None, 1, 1, 6)   │        870 │ block3a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_expand   │ (None, 1, 1, 144) │      1,008 │ block3a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_excite   │ (None, 28, 28,    │          0 │ block3a_activati… │
# │ (Multiply)          │ 144)              │            │ block3a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_project_co… │ (None, 28, 28,    │      5,760 │ block3a_se_excit… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_project_bn  │ (None, 28, 28,    │        160 │ block3a_project_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_conv │ (None, 28, 28,    │      9,600 │ block3a_project_… │
# │ (Conv2D)            │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_bn   │ (None, 28, 28,    │        960 │ block3b_expand_c… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_act… │ (None, 28, 28,    │          0 │ block3b_expand_b… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_dwconv      │ (None, 28, 28,    │      6,000 │ block3b_expand_a… │
# │ (DepthwiseConv2D)   │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_bn          │ (None, 28, 28,    │        960 │ block3b_dwconv[0… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_activation  │ (None, 28, 28,    │          0 │ block3b_bn[0][0]  │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_squeeze  │ (None, 240)       │          0 │ block3b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_reshape  │ (None, 1, 1, 240) │          0 │ block3b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_reduce   │ (None, 1, 1, 10)  │      2,410 │ block3b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_expand   │ (None, 1, 1, 240) │      2,640 │ block3b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_excite   │ (None, 28, 28,    │          0 │ block3b_activati… │
# │ (Multiply)          │ 240)              │            │ block3b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_project_co… │ (None, 28, 28,    │      9,600 │ block3b_se_excit… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_project_bn  │ (None, 28, 28,    │        160 │ block3b_project_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_drop        │ (None, 28, 28,    │          0 │ block3b_project_… │
# │ (Dropout)           │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_add (Add)   │ (None, 28, 28,    │          0 │ block3b_drop[0][… │
# │                     │ 40)               │            │ block3a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_conv │ (None, 28, 28,    │      9,600 │ block3b_add[0][0] │
# │ (Conv2D)            │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_bn   │ (None, 28, 28,    │        960 │ block4a_expand_c… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_act… │ (None, 28, 28,    │          0 │ block4a_expand_b… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_dwconv_pad  │ (None, 29, 29,    │          0 │ block4a_expand_a… │
# │ (ZeroPadding2D)     │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_dwconv      │ (None, 14, 14,    │      2,160 │ block4a_dwconv_p… │
# │ (DepthwiseConv2D)   │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_bn          │ (None, 14, 14,    │        960 │ block4a_dwconv[0… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_activation  │ (None, 14, 14,    │          0 │ block4a_bn[0][0]  │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_squeeze  │ (None, 240)       │          0 │ block4a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_reshape  │ (None, 1, 1, 240) │          0 │ block4a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_reduce   │ (None, 1, 1, 10)  │      2,410 │ block4a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_expand   │ (None, 1, 1, 240) │      2,640 │ block4a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_excite   │ (None, 14, 14,    │          0 │ block4a_activati… │
# │ (Multiply)          │ 240)              │            │ block4a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_project_co… │ (None, 14, 14,    │     19,200 │ block4a_se_excit… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_project_bn  │ (None, 14, 14,    │        320 │ block4a_project_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_conv │ (None, 14, 14,    │     38,400 │ block4a_project_… │
# │ (Conv2D)            │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_bn   │ (None, 14, 14,    │      1,920 │ block4b_expand_c… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_act… │ (None, 14, 14,    │          0 │ block4b_expand_b… │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_dwconv      │ (None, 14, 14,    │      4,320 │ block4b_expand_a… │
# │ (DepthwiseConv2D)   │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_bn          │ (None, 14, 14,    │      1,920 │ block4b_dwconv[0… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_activation  │ (None, 14, 14,    │          0 │ block4b_bn[0][0]  │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_squeeze  │ (None, 480)       │          0 │ block4b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_reshape  │ (None, 1, 1, 480) │          0 │ block4b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_reduce   │ (None, 1, 1, 20)  │      9,620 │ block4b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_expand   │ (None, 1, 1, 480) │     10,080 │ block4b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_excite   │ (None, 14, 14,    │          0 │ block4b_activati… │
# │ (Multiply)          │ 480)              │            │ block4b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_project_co… │ (None, 14, 14,    │     38,400 │ block4b_se_excit… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_project_bn  │ (None, 14, 14,    │        320 │ block4b_project_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_drop        │ (None, 14, 14,    │          0 │ block4b_project_… │
# │ (Dropout)           │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_add (Add)   │ (None, 14, 14,    │          0 │ block4b_drop[0][… │
# │                     │ 80)               │            │ block4a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_expand_conv │ (None, 14, 14,    │     38,400 │ block4b_add[0][0] │
# │ (Conv2D)            │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_expand_bn   │ (None, 14, 14,    │      1,920 │ block4c_expand_c… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_expand_act… │ (None, 14, 14,    │          0 │ block4c_expand_b… │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_dwconv      │ (None, 14, 14,    │      4,320 │ block4c_expand_a… │
# │ (DepthwiseConv2D)   │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_bn          │ (None, 14, 14,    │      1,920 │ block4c_dwconv[0… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_activation  │ (None, 14, 14,    │          0 │ block4c_bn[0][0]  │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_squeeze  │ (None, 480)       │          0 │ block4c_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_reshape  │ (None, 1, 1, 480) │          0 │ block4c_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_reduce   │ (None, 1, 1, 20)  │      9,620 │ block4c_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_expand   │ (None, 1, 1, 480) │     10,080 │ block4c_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_excite   │ (None, 14, 14,    │          0 │ block4c_activati… │
# │ (Multiply)          │ 480)              │            │ block4c_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_project_co… │ (None, 14, 14,    │     38,400 │ block4c_se_excit… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_project_bn  │ (None, 14, 14,    │        320 │ block4c_project_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_drop        │ (None, 14, 14,    │          0 │ block4c_project_… │
# │ (Dropout)           │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_add (Add)   │ (None, 14, 14,    │          0 │ block4c_drop[0][… │
# │                     │ 80)               │            │ block4b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_expand_conv │ (None, 14, 14,    │     38,400 │ block4c_add[0][0] │
# │ (Conv2D)            │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_expand_bn   │ (None, 14, 14,    │      1,920 │ block5a_expand_c… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_expand_act… │ (None, 14, 14,    │          0 │ block5a_expand_b… │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_dwconv      │ (None, 14, 14,    │     12,000 │ block5a_expand_a… │
# │ (DepthwiseConv2D)   │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_bn          │ (None, 14, 14,    │      1,920 │ block5a_dwconv[0… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_activation  │ (None, 14, 14,    │          0 │ block5a_bn[0][0]  │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_squeeze  │ (None, 480)       │          0 │ block5a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_reshape  │ (None, 1, 1, 480) │          0 │ block5a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_reduce   │ (None, 1, 1, 20)  │      9,620 │ block5a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_expand   │ (None, 1, 1, 480) │     10,080 │ block5a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_excite   │ (None, 14, 14,    │          0 │ block5a_activati… │
# │ (Multiply)          │ 480)              │            │ block5a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_project_co… │ (None, 14, 14,    │     53,760 │ block5a_se_excit… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_project_bn  │ (None, 14, 14,    │        448 │ block5a_project_… │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_expand_conv │ (None, 14, 14,    │     75,264 │ block5a_project_… │
# │ (Conv2D)            │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_expand_bn   │ (None, 14, 14,    │      2,688 │ block5b_expand_c… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_expand_act… │ (None, 14, 14,    │          0 │ block5b_expand_b… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_dwconv      │ (None, 14, 14,    │     16,800 │ block5b_expand_a… │
# │ (DepthwiseConv2D)   │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_bn          │ (None, 14, 14,    │      2,688 │ block5b_dwconv[0… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_activation  │ (None, 14, 14,    │          0 │ block5b_bn[0][0]  │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_squeeze  │ (None, 672)       │          0 │ block5b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_reshape  │ (None, 1, 1, 672) │          0 │ block5b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_reduce   │ (None, 1, 1, 28)  │     18,844 │ block5b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_expand   │ (None, 1, 1, 672) │     19,488 │ block5b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_excite   │ (None, 14, 14,    │          0 │ block5b_activati… │
# │ (Multiply)          │ 672)              │            │ block5b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_project_co… │ (None, 14, 14,    │     75,264 │ block5b_se_excit… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_project_bn  │ (None, 14, 14,    │        448 │ block5b_project_… │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_drop        │ (None, 14, 14,    │          0 │ block5b_project_… │
# │ (Dropout)           │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_add (Add)   │ (None, 14, 14,    │          0 │ block5b_drop[0][… │
# │                     │ 112)              │            │ block5a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_expand_conv │ (None, 14, 14,    │     75,264 │ block5b_add[0][0] │
# │ (Conv2D)            │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_expand_bn   │ (None, 14, 14,    │      2,688 │ block5c_expand_c… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_expand_act… │ (None, 14, 14,    │          0 │ block5c_expand_b… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_dwconv      │ (None, 14, 14,    │     16,800 │ block5c_expand_a… │
# │ (DepthwiseConv2D)   │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_bn          │ (None, 14, 14,    │      2,688 │ block5c_dwconv[0… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_activation  │ (None, 14, 14,    │          0 │ block5c_bn[0][0]  │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_squeeze  │ (None, 672)       │          0 │ block5c_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_reshape  │ (None, 1, 1, 672) │          0 │ block5c_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_reduce   │ (None, 1, 1, 28)  │     18,844 │ block5c_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_expand   │ (None, 1, 1, 672) │     19,488 │ block5c_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_excite   │ (None, 14, 14,    │          0 │ block5c_activati… │
# │ (Multiply)          │ 672)              │            │ block5c_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_project_co… │ (None, 14, 14,    │     75,264 │ block5c_se_excit… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_project_bn  │ (None, 14, 14,    │        448 │ block5c_project_… │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_drop        │ (None, 14, 14,    │          0 │ block5c_project_… │
# │ (Dropout)           │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_add (Add)   │ (None, 14, 14,    │          0 │ block5c_drop[0][… │
# │                     │ 112)              │            │ block5b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_expand_conv │ (None, 14, 14,    │     75,264 │ block5c_add[0][0] │
# │ (Conv2D)            │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_expand_bn   │ (None, 14, 14,    │      2,688 │ block6a_expand_c… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_expand_act… │ (None, 14, 14,    │          0 │ block6a_expand_b… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_dwconv_pad  │ (None, 17, 17,    │          0 │ block6a_expand_a… │
# │ (ZeroPadding2D)     │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_dwconv      │ (None, 7, 7, 672) │     16,800 │ block6a_dwconv_p… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_bn          │ (None, 7, 7, 672) │      2,688 │ block6a_dwconv[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_activation  │ (None, 7, 7, 672) │          0 │ block6a_bn[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_squeeze  │ (None, 672)       │          0 │ block6a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_reshape  │ (None, 1, 1, 672) │          0 │ block6a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_reduce   │ (None, 1, 1, 28)  │     18,844 │ block6a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_expand   │ (None, 1, 1, 672) │     19,488 │ block6a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_excite   │ (None, 7, 7, 672) │          0 │ block6a_activati… │
# │ (Multiply)          │                   │            │ block6a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_project_co… │ (None, 7, 7, 192) │    129,024 │ block6a_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_project_bn  │ (None, 7, 7, 192) │        768 │ block6a_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_expand_conv │ (None, 7, 7,      │    221,184 │ block6a_project_… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_expand_bn   │ (None, 7, 7,      │      4,608 │ block6b_expand_c… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_expand_act… │ (None, 7, 7,      │          0 │ block6b_expand_b… │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_dwconv      │ (None, 7, 7,      │     28,800 │ block6b_expand_a… │
# │ (DepthwiseConv2D)   │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_bn          │ (None, 7, 7,      │      4,608 │ block6b_dwconv[0… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_activation  │ (None, 7, 7,      │          0 │ block6b_bn[0][0]  │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_squeeze  │ (None, 1152)      │          0 │ block6b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_reshape  │ (None, 1, 1,      │          0 │ block6b_se_squee… │
# │ (Reshape)           │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_reduce   │ (None, 1, 1, 48)  │     55,344 │ block6b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_expand   │ (None, 1, 1,      │     56,448 │ block6b_se_reduc… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_excite   │ (None, 7, 7,      │          0 │ block6b_activati… │
# │ (Multiply)          │ 1152)             │            │ block6b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_project_co… │ (None, 7, 7, 192) │    221,184 │ block6b_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_project_bn  │ (None, 7, 7, 192) │        768 │ block6b_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_drop        │ (None, 7, 7, 192) │          0 │ block6b_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_add (Add)   │ (None, 7, 7, 192) │          0 │ block6b_drop[0][… │
# │                     │                   │            │ block6a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_expand_conv │ (None, 7, 7,      │    221,184 │ block6b_add[0][0] │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_expand_bn   │ (None, 7, 7,      │      4,608 │ block6c_expand_c… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_expand_act… │ (None, 7, 7,      │          0 │ block6c_expand_b… │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_dwconv      │ (None, 7, 7,      │     28,800 │ block6c_expand_a… │
# │ (DepthwiseConv2D)   │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_bn          │ (None, 7, 7,      │      4,608 │ block6c_dwconv[0… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_activation  │ (None, 7, 7,      │          0 │ block6c_bn[0][0]  │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_squeeze  │ (None, 1152)      │          0 │ block6c_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_reshape  │ (None, 1, 1,      │          0 │ block6c_se_squee… │
# │ (Reshape)           │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_reduce   │ (None, 1, 1, 48)  │     55,344 │ block6c_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_expand   │ (None, 1, 1,      │     56,448 │ block6c_se_reduc… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_excite   │ (None, 7, 7,      │          0 │ block6c_activati… │
# │ (Multiply)          │ 1152)             │            │ block6c_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_project_co… │ (None, 7, 7, 192) │    221,184 │ block6c_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_project_bn  │ (None, 7, 7, 192) │        768 │ block6c_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_drop        │ (None, 7, 7, 192) │          0 │ block6c_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_add (Add)   │ (None, 7, 7, 192) │          0 │ block6c_drop[0][… │
# │                     │                   │            │ block6b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_expand_conv │ (None, 7, 7,      │    221,184 │ block6c_add[0][0] │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_expand_bn   │ (None, 7, 7,      │      4,608 │ block6d_expand_c… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_expand_act… │ (None, 7, 7,      │          0 │ block6d_expand_b… │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_dwconv      │ (None, 7, 7,      │     28,800 │ block6d_expand_a… │
# │ (DepthwiseConv2D)   │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_bn          │ (None, 7, 7,      │      4,608 │ block6d_dwconv[0… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_activation  │ (None, 7, 7,      │          0 │ block6d_bn[0][0]  │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_squeeze  │ (None, 1152)      │          0 │ block6d_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_reshape  │ (None, 1, 1,      │          0 │ block6d_se_squee… │
# │ (Reshape)           │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_reduce   │ (None, 1, 1, 48)  │     55,344 │ block6d_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_expand   │ (None, 1, 1,      │     56,448 │ block6d_se_reduc… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_excite   │ (None, 7, 7,      │          0 │ block6d_activati… │
# │ (Multiply)          │ 1152)             │            │ block6d_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_project_co… │ (None, 7, 7, 192) │    221,184 │ block6d_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_project_bn  │ (None, 7, 7, 192) │        768 │ block6d_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_drop        │ (None, 7, 7, 192) │          0 │ block6d_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_add (Add)   │ (None, 7, 7, 192) │          0 │ block6d_drop[0][… │
# │                     │                   │            │ block6c_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_expand_conv │ (None, 7, 7,      │    221,184 │ block6d_add[0][0] │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_expand_bn   │ (None, 7, 7,      │      4,608 │ block7a_expand_c… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_expand_act… │ (None, 7, 7,      │          0 │ block7a_expand_b… │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_dwconv      │ (None, 7, 7,      │     10,368 │ block7a_expand_a… │
# │ (DepthwiseConv2D)   │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_bn          │ (None, 7, 7,      │      4,608 │ block7a_dwconv[0… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_activation  │ (None, 7, 7,      │          0 │ block7a_bn[0][0]  │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_squeeze  │ (None, 1152)      │          0 │ block7a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_reshape  │ (None, 1, 1,      │          0 │ block7a_se_squee… │
# │ (Reshape)           │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_reduce   │ (None, 1, 1, 48)  │     55,344 │ block7a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_expand   │ (None, 1, 1,      │     56,448 │ block7a_se_reduc… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_excite   │ (None, 7, 7,      │          0 │ block7a_activati… │
# │ (Multiply)          │ 1152)             │            │ block7a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_project_co… │ (None, 7, 7, 320) │    368,640 │ block7a_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_project_bn  │ (None, 7, 7, 320) │      1,280 │ block7a_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_conv (Conv2D)   │ (None, 7, 7,      │    409,600 │ block7a_project_… │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_bn              │ (None, 7, 7,      │      5,120 │ top_conv[0][0]    │
# │ (BatchNormalizatio… │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_activation      │ (None, 7, 7,      │          0 │ top_bn[0][0]      │
# │ (Activation)        │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ avg_pool            │ (None, 1280)      │          0 │ top_activation[0… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 1280)      │      5,120 │ avg_pool[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_dropout         │ (None, 1280)      │          0 │ batch_normalizat… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pred (Dense)        │ (None, 7)         │      8,967 │ top_dropout[0][0] │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 4,063,658 (15.50 MB)
#  Trainable params: 11,527 (45.03 KB)
#  Non-trainable params: 4,052,131 (15.46 MB)

# %% [markdown]
# 6. Configuración del entrenamiento

# %%
# Tabla de configuración
config_df = pd.DataFrame({
    'Parámetro': ['Optimizer', 'Loss Function', 'Batch Size', 'Img Size', 'Base Trainable (Fase 1)'],
    'Valor': ['Adam', 'Categorical Crossentropy', BATCH_SIZE, IMG_SIZE, 'False']
})
display(config_df)

# Callbacks
callbacks = [
    ModelCheckpoint(BEST_MODEL_PATH, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1),
    EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, min_lr=1e-6, verbose=1)
]

# Compilación Fase 1
model.compile(
    optimizer=optimizers.Adam(learning_rate=1e-3),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
#                  Parámetro                     Valor
# 0                Optimizer                      Adam
# 1            Loss Function  Categorical Crossentropy
# 2               Batch Size                        32
# 3                 Img Size                (224, 224)
# 4  Base Trainable (Fase 1)                     False

# %% [markdown]
# TABLA 4: CONFIGURACIÓN DE HIPERPARÁMETROS

# %%
# ==========================================
# TABLA 4: CONFIGURACIÓN DE HIPERPARÁMETROS
# ==========================================

training_config = [
    ["Arquitectura Base", "EfficientNetB0", "Pre-entrenada en ImageNet"],
    ["Pesos Iniciales", "ImageNet", "Transfer Learning"],
    ["Input Shape", f"{INPUT_SHAPE}", "Resolución 224x224x3"],
    ["Optimizador", "Adam", "Algoritmo adaptativo"],
    ["Loss Function", "Categorical Crossentropy", "Para clasificación multiclase one-hot"],
    ["Learning Rate (Fase 1)", "0.001 (1e-3)", "Entrenamiento rápido de la cabeza"],
    ["Learning Rate (Fase 2)", "0.00001 (1e-5)", "Fine-Tuning lento y preciso"],
    ["Batch Size", f"{BATCH_SIZE}", "Balance entre velocidad y memoria"],
    ["Épocas Fase 1 (Head)", f"{NUM_EPOCHS_HEAD}", "Adaptación de nuevas clases"],
    ["Épocas Fase 2 (Fine-Tune)", f"{NUM_EPOCHS_FINE}", "Ajuste fino de pesos profundos"],
    ["Dropout", "0.3 (30%)", "Prevención de Overfitting en capa densa"],
    ["Early Stopping", "Patience=5", "Detiene si no mejora val_accuracy"]
]

df_config = pd.DataFrame(training_config, columns=["Hiperparámetro / Configuración", "Valor", "Descripción"])

print("\n⚙️ Tabla 4: Configuración del Experimento")
display(df_config)
# Out:
# ⚙️ Tabla 4: Configuración del Experimento
#    Hiperparámetro / Configuración                     Valor  \
# 0               Arquitectura Base            EfficientNetB0
# 1                 Pesos Iniciales                  ImageNet
# 2                     Input Shape             (224, 224, 3)
# 3                     Optimizador                      Adam
# 4                   Loss Function  Categorical Crossentropy
# 5          Learning Rate (Fase 1)              0.001 (1e-3)
# 6          Learning Rate (Fase 2)            0.00001 (1e-5)
# 7                      Batch Size                        32
# 8            Épocas Fase 1 (Head)                         5
# 9       Épocas Fase 2 (Fine-Tune)                        15
# 10                        Dropout                 0.3 (30%)
# 11                 Early Stopping                Patience=5
#
#                                 Descripción
# 0                 Pre-entrenada en ImageNet
# 1                         Transfer Learning
# 2                      Resolución 224x224x3
# 3                      Algoritmo adaptativo
# 4     Para clasificación multiclase one-hot
# 5         Entrenamiento rápido de la cabeza
# 6               Fine-Tuning lento y preciso
# 7         Balance entre velocidad y memoria
# 8               Adaptación de nuevas clases
# 9            Ajuste fino de pesos profundos
# 10  Prevención de Overfitting en capa densa
# 11        Detiene si no mejora val_accuracy

# %% [markdown]
# 7. Entrenamiento del modelo

# %%
# --- FASE 1: Feature Extraction ---
print(f"\n🚀 Iniciando Fase 1: Entrenamiento de la cabeza ({NUM_EPOCHS_HEAD} épocas)...")
start_time = time.time()

history_1 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=NUM_EPOCHS_HEAD,
    callbacks=callbacks
)

phase1_time = time.time() - start_time

# --- FASE 2: Fine-Tuning ---
print(f"\n🔓 Descongelando capas para Fine-Tuning...")
base_model.trainable = True

# Congelamos las primeras capas para preservar características básicas
for layer in base_model.layers:
    if "block5" in layer.name or "block6" in layer.name or "block7" in layer.name:
        layer.trainable = True
    else:
        layer.trainable = False

# Recompilamos con un Learning Rate mucho menor
model.compile(
    optimizer=optimizers.Adam(learning_rate=1e-5),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

print(f"🚀 Iniciando Fase 2: Fine-Tuning ({NUM_EPOCHS_FINE} épocas)...")
start_time_2 = time.time()

# Ajustamos epoch inicial para que la gráfica sea continua
history_2 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=NUM_EPOCHS_HEAD + NUM_EPOCHS_FINE,
    initial_epoch=history_1.epoch[-1] + 1,
    callbacks=callbacks
)

phase2_time = time.time() - start_time_2

# Tabla de tiempos
time_df = pd.DataFrame({
    'Fase': ['Feature Extraction', 'Fine-Tuning', 'Total'],
    'Tiempo (min)': [phase1_time/60, phase2_time/60, (phase1_time+phase2_time)/60]
})
display(time_df)
# Out:
# 🚀 Iniciando Fase 1: Entrenamiento de la cabeza (5 épocas)...
# Epoch 1/5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.5347 - loss: 1.3925
# Epoch 1: val_accuracy improved from -inf to 0.72571, saving model to /content/drive/MyDrive/Entrenamiento con balanceo/EfficientNetB0/banano_efficientnetb0_best_scientific.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 925s 8s/step - accuracy: 0.5358 - loss: 1.3892 - val_accuracy: 0.7257 - val_loss: 0.9082 - learning_rate: 0.0010
# Epoch 2/5
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.8324 - loss: 0.5144
# Epoch 2: val_accuracy improved from 0.72571 to 0.83143, saving model to /content/drive/MyDrive/Entrenamiento con balanceo/EfficientNetB0/banano_efficientnetb0_best_scientific.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 18s 90ms/step - accuracy: 0.8323 - loss: 0.5144 - val_accuracy: 0.8314 - val_loss: 0.5774 - learning_rate: 0.0010
# Epoch 3/5
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8658 - loss: 0.3955
# Epoch 3: val_accuracy improved from 0.83143 to 0.85429, saving model to /content/drive/MyDrive/Entrenamiento con balanceo/EfficientNetB0/banano_efficientnetb0_best_scientific.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 10s 88ms/step - accuracy: 0.8658 - loss: 0.3956 - val_accuracy: 0.8543 - val_loss: 0.4000 - learning_rate: 0.0010
# Epoch 4/5
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8848 - loss: 0.3353
# Epoch 4: val_accuracy improved from 0.85429 to 0.90286, saving model to /content/drive/MyDrive/Entrenamiento con balanceo/EfficientNetB0/banano_efficientnetb0_best_scientific.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 9s 86ms/step - accuracy: 0.8848 - loss: 0.3355 - val_accuracy: 0.9029 - val_loss: 0.2939 - learning_rate: 0.0010
# Epoch 5/5
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9032 - loss: 0.2830
# Epoch 5: val_accuracy improved from 0.90286 to 0.92000, saving model to /content/drive/MyDrive/Entrenamiento con balanceo/EfficientNetB0/banano_efficientnetb0_best_scientific.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - accuracy: 0.9031 - loss: 0.2833 - val_accuracy: 0.9200 - val_loss: 0.2428 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 5.
#
# 🔓 Descongelando capas para Fine-Tuning...
# 🚀 Iniciando Fase 2: Fine-Tuning (15 épocas)...
# Epoch 6/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.5897 - loss: 1.2661
# Epoch 6: val_accuracy did not improve from 0.92000
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 44s 183ms/step - accuracy: 0.5901 - loss: 1.2648 - val_accuracy: 0.8543 - val_loss: 0.3307 - learning_rate: 1.0000e-05
# Epoch 7/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.7156 - loss: 0.8412
# Epoch 7: val_accuracy did not improve from 0.92000
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 17s 152ms/step - accuracy: 0.7157 - loss: 0.8410 - val_accuracy: 0.8600 - val_loss: 0.3780 - learning_rate: 1.0000e-05
# Epoch 8/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.7753 - loss: 0.6518
# Epoch 8: val_accuracy did not improve from 0.92000
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 17s 152ms/step - accuracy: 0.7753 - loss: 0.6516 - val_accuracy: 0.8686 - val_loss: 0.3666 - learning_rate: 1.0000e-05
# Epoch 9/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.8180 - loss: 0.5263
# Epoch 9: val_accuracy did not improve from 0.92000
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 16s 149ms/step - accuracy: 0.8179 - loss: 0.5265 - val_accuracy: 0.8686 - val_loss: 0.3644 - learning_rate: 5.0000e-06
# Epoch 10/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.8157 - loss: 0.5254
# Epoch 10: val_accuracy did not improve from 0.92000
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 17s 152ms/step - accuracy: 0.8157 - loss: 0.5255 - val_accuracy: 0.8800 - val_loss: 0.3440 - learning_rate: 5.0000e-06
# Epoch 11/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.8408 - loss: 0.4651
# Epoch 11: val_accuracy did not improve from 0.92000
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 16s 149ms/step - accuracy: 0.8407 - loss: 0.4652 - val_accuracy: 0.8800 - val_loss: 0.3331 - learning_rate: 2.5000e-06
# Epoch 12/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.8573 - loss: 0.4375
# Epoch 12: val_accuracy did not improve from 0.92000
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 17s 151ms/step - accuracy: 0.8572 - loss: 0.4377 - val_accuracy: 0.8914 - val_loss: 0.3214 - learning_rate: 2.5000e-06
# Epoch 13/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.8496 - loss: 0.4402
# Epoch 13: val_accuracy did not improve from 0.92000
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 17s 152ms/step - accuracy: 0.8496 - loss: 0.4403 - val_accuracy: 0.8943 - val_loss: 0.3111 - learning_rate: 2.5000e-06
# Epoch 14/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.8486 - loss: 0.4345
# Epoch 14: val_accuracy did not improve from 0.92000
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 17s 152ms/step - accuracy: 0.8486 - loss: 0.4345 - val_accuracy: 0.8971 - val_loss: 0.2997 - learning_rate: 2.5000e-06
# Epoch 15/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8458 - loss: 0.4209
# Epoch 15: val_accuracy did not improve from 0.92000
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 16s 150ms/step - accuracy: 0.8459 - loss: 0.4208 - val_accuracy: 0.8971 - val_loss: 0.2877 - learning_rate: 2.5000e-06
# Epoch 16/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8635 - loss: 0.4112
# Epoch 16: val_accuracy did not improve from 0.92000
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 17s 150ms/step - accuracy: 0.8635 - loss: 0.4112 - val_accuracy: 0.9029 - val_loss: 0.2753 - learning_rate: 2.5000e-06
# Epoch 17/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.8679 - loss: 0.3879
# Epoch 17: val_accuracy did not improve from 0.92000
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 17s 153ms/step - accuracy: 0.8679 - loss: 0.3879 - val_accuracy: 0.9057 - val_loss: 0.2670 - learning_rate: 2.5000e-06
# Epoch 18/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.8779 - loss: 0.3539
# Epoch 18: val_accuracy did not improve from 0.92000
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 17s 150ms/step - accuracy: 0.8779 - loss: 0.3540 - val_accuracy: 0.9057 - val_loss: 0.2614 - learning_rate: 2.5000e-06
# Epoch 19/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8731 - loss: 0.3596
# Epoch 19: val_accuracy did not improve from 0.92000
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 17s 151ms/step - accuracy: 0.8731 - loss: 0.3595 - val_accuracy: 0.9143 - val_loss: 0.2515 - learning_rate: 2.5000e-06
# Epoch 20/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8838 - loss: 0.3396
# Epoch 20: val_accuracy did not improve from 0.92000
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 16s 150ms/step - accuracy: 0.8837 - loss: 0.3397 - val_accuracy: 0.9143 - val_loss: 0.2449 - learning_rate: 2.5000e-06
# Restoring model weights from the end of the best epoch: 19.
#                  Fase  Tiempo (min)
# 0  Feature Extraction     16.196505
# 1         Fine-Tuning      4.617825
# 2               Total     20.814331

# %% [markdown]
# 8. Curvas de aprendizaje

# %%
def plot_training_history(h1, h2):
    acc = h1.history['accuracy'] + h2.history['accuracy']
    val_acc = h1.history['val_accuracy'] + h2.history['val_accuracy']
    loss = h1.history['loss'] + h2.history['loss']
    val_loss = h1.history['val_loss'] + h2.history['val_loss']

    epochs_range = range(len(acc))

    plt.figure(figsize=(14, 6))

    # Accuracy
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.axvline(x=len(h1.history['accuracy'])-1, color='green', linestyle='--', label='Inicio Fine-Tuning')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.grid(True)

    # Loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.axvline(x=len(h1.history['loss'])-1, color='green', linestyle='--', label='Inicio Fine-Tuning')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.grid(True)

    plt.show()

plot_training_history(history_1, history_2)

# %% [markdown]
# 9. Evaluación del modelo (Cálculo de métricas detalladas)

# %%
print("\n🧪 Evaluando modelo en Test Set...")

# Obtener etiquetas verdaderas y predicciones
y_true = []
y_pred_probs = []

# Iterar sobre el dataset de test (sin shuffle)
for images, labels in test_ds:
    y_true.extend(np.argmax(labels.numpy(), axis=1))
    preds = model.predict(images, verbose=0)
    y_pred_probs.extend(preds)

y_true = np.array(y_true)
y_pred_probs = np.array(y_pred_probs)
y_pred = np.argmax(y_pred_probs, axis=1)

# Cálculo de métricas One-vs-All por clase
metrics_list = []

for i, class_name in enumerate(class_names):
    # Crear etiquetas binarias para la clase actual vs resto
    y_true_cls = (y_true == i).astype(int)
    y_pred_cls = (y_pred == i).astype(int)

    # Matriz de confusión binaria
    tn, fp, fn, tp = confusion_matrix(y_true_cls, y_pred_cls).ravel()

    # Métricas
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    precision = tp / (tp + fp) if (tp + fp) > 0 else 0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0  # Sensitivity / TPR
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0 # TNR
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
    fpr = fp / (tn + fp) if (tn + fp) > 0 else 0
    youden = recall + specificity - 1

    # AUC One-vs-Rest
    try:
        auc = roc_auc_score(y_true_cls, y_pred_probs[:, i])
    except ValueError:
        auc = 0.0

    support = tp + fn

    metrics_list.append({
        'Class': class_name,
        'Accuracy': accuracy,
        'Precision': precision,
        'Recall (Sens)': recall,
        'Specificity': specificity,
        'F1-Score': f1,
        'AUC': auc,
        'Youden Index': youden,
        'FPR': fpr,
        'TP': tp, 'TN': tn, 'FP': fp, 'FN': fn,
        'Support': support
    })

metrics_df = pd.DataFrame(metrics_list)
# Out:
# 🧪 Evaluando modelo en Test Set...

# %% [markdown]
# 10. Matriz de Confusión

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.ylabel('Etiqueta Verdadera')
plt.xlabel('Etiqueta Predicha')
plt.title('Matriz de Confusión - EfficientNetB0')
plt.show()

# %% [markdown]
# 11. Tablas de métricas

# %%
# 11.1 Tabla por Clase
print("\n📊 Métricas Detalladas por Clase:")
display(metrics_df.round(4))

# 11.2 Métricas Globales (Weighted Average)
global_metrics = {
    'Global Accuracy': accuracy_score(y_true, y_pred),
    'Weighted Precision': precision_score(y_true, y_pred, average='weighted'),
    'Weighted Recall': recall_score(y_true, y_pred, average='weighted'),
    'Weighted F1': f1_score(y_true, y_pred, average='weighted'),
    'Macro Recall': recall_score(y_true, y_pred, average='macro'),
    'Macro AUC': roc_auc_score(y_true, y_pred_probs, multi_class='ovr', average='macro')
}

global_df = pd.DataFrame([global_metrics])
print("\n🌍 Métricas Globales:")
display(global_df.round(4))
# Out:
# 📊 Métricas Detalladas por Clase:
#                 Class  Accuracy  Precision  Recall (Sens)  Specificity  \
# 0                apto    1.0000     1.0000           1.00       1.0000
# 1     cascara_partida    0.9714     0.8704           0.94       0.9767
# 2      cicatriz_golpe    0.9571     0.8889           0.80       0.9833
# 3     corte_cuchareta    0.9829     0.9231           0.96       0.9867
# 4     mal_formaciones    0.9657     0.9130           0.84       0.9867
# 5       marca_madurez    0.9771     0.8889           0.96       0.9800
# 6  plaga_enfermedades    0.9743     0.9184           0.90       0.9867
#
#    F1-Score     AUC  Youden Index     FPR  TP   TN  FP  FN  Support
# 0    1.0000  1.0000        1.0000  0.0000  50  300   0   0       50
# 1    0.9038  0.9945        0.9167  0.0233  47  293   7   3       50
# 2    0.8421  0.9873        0.7833  0.0167  40  295   5  10       50
# 3    0.9412  0.9991        0.9467  0.0133  48  296   4   2       50
# 4    0.8750  0.9826        0.8267  0.0133  42  296   4   8       50
# 5    0.9231  0.9960        0.9400  0.0200  48  294   6   2       50
# 6    0.9091  0.9985        0.8867  0.0133  45  296   4   5       50
# 🌍 Métricas Globales:
#    Global Accuracy  Weighted Precision  Weighted Recall  Weighted F1  \
# 0           0.9143              0.9147           0.9143       0.9135
#
#    Macro Recall  Macro AUC
# 0        0.9143      0.994

# %% [markdown]
# 12. Evaluación del mejor modelo

# %%
print(f"\n🏆 Cargando el mejor modelo guardado desde: {BEST_MODEL_PATH}")
try:
    best_model = tf.keras.models.load_model(BEST_MODEL_PATH)

    # Evaluación rápida del mejor modelo
    loss, acc = best_model.evaluate(test_ds, verbose=0)
    print(f"Best Model Test Accuracy: {acc:.4f}")
    print(f"Best Model Test Loss: {loss:.4f}")

    # Comprobación de selección
    if acc > global_metrics['Global Accuracy']:
        print("✅ El modelo guardado es mejor que el modelo final en memoria.")
    else:
        print("ℹ️ El modelo en memoria tiene un rendimiento similar o igual.")

except Exception as e:
    print(f"Error cargando el modelo: {e}")
# Out:
# 🏆 Cargando el mejor modelo guardado desde: /content/drive/MyDrive/Entrenamiento con balanceo/EfficientNetB0/banano_efficientnetb0_best_scientific.keras
# Best Model Test Accuracy: 0.9143
# Best Model Test Loss: 0.2574
# ✅ El modelo guardado es mejor que el modelo final en memoria.

# %% [markdown]
# 13. Resultados finales y Conclusiones

# %%
# Generar reporte de texto estándar de scikit-learn para complementar
print("\n📝 Classification Report (Scikit-Learn Standard):")
print(classification_report(y_true, y_pred, target_names=class_names))

# Análisis de resultados (Markdown generado dinámicamente)
best_class = metrics_df.loc[metrics_df['F1-Score'].idxmax()]
worst_class = metrics_df.loc[metrics_df['F1-Score'].idxmin()]

print("="*50)
print("CONCLUSIONES DEL EXPERIMENTO")
print("="*50)
print(f"1. Rendimiento Global: El modelo alcanzó una exactitud (Top-1 Accuracy) del {global_metrics['Global Accuracy']:.2%}.")
print(f"2. Mejor Clase: '{best_class['Class']}' con un F1-Score de {best_class['F1-Score']:.4f}.")
print(f"3. Peor Clase: '{worst_class['Class']}' con un F1-Score de {worst_class['F1-Score']:.4f}. (Posible confusión visual).")
print(f"4. Discriminación: El AUC promedio es {global_metrics['Macro AUC']:.4f}, indicando una { 'excelente' if global_metrics['Macro AUC'] > 0.9 else 'buena' } capacidad de separación entre clases.")
print(f"5. Tiempos: El entrenamiento total tomó aproximadamente {(phase1_time+phase2_time)/60:.1f} minutos.")
print("="*50)
# Out:
# 📝 Classification Report (Scikit-Learn Standard):
#                     precision    recall  f1-score   support
#
#               apto       1.00      1.00      1.00        50
#    cascara_partida       0.87      0.94      0.90        50
#     cicatriz_golpe       0.89      0.80      0.84        50
#    corte_cuchareta       0.92      0.96      0.94        50
#    mal_formaciones       0.91      0.84      0.88        50
#      marca_madurez       0.89      0.96      0.92        50
# plaga_enfermedades       0.92      0.90      0.91        50
#
#           accuracy                           0.91       350
#          macro avg       0.91      0.91      0.91       350
#       weighted avg       0.91      0.91      0.91       350
#
# ==================================================
# CONCLUSIONES DEL EXPERIMENTO
# ==================================================
# 1. Rendimiento Global: El modelo alcanzó una exactitud (Top-1 Accuracy) del 91.43%.
# 2. Mejor Clase: 'apto' con un F1-Score de 1.0000.
# 3. Peor Clase: 'cicatriz_golpe' con un F1-Score de 0.8421. (Posible confusión visual).
# 4. Discriminación: El AUC promedio es 0.9940, indicando una excelente capacidad de separación entre clases.
# 5. Tiempos: El entrenamiento total tomó aproximadamente 20.8 minutos.
# ==================================================

# %% [markdown]
# 14. EXPORTACIÓN DEL MODELO Y ETIQUETAS (DEPLOYMENT)

# %%
import tensorflow as tf
import os

# =========================================================
# 14. EXPORTACIÓN DEL MODELO Y ETIQUETAS (DEPLOYMENT)
# =========================================================

print(f"\n📲 Preparando archivos para despliegue en móvil...")

# ---------------------------------------------------------
# PASO 1: Convertir el modelo .keras a .tflite
# ---------------------------------------------------------
print("1️⃣  Cargando el mejor modelo guardado (.keras)...")

# Verificar que existe el archivo antes de cargar
if not os.path.exists(BEST_MODEL_PATH):
    raise FileNotFoundError(f"❌ No se encontró el modelo en: {BEST_MODEL_PATH}")

model = tf.keras.models.load_model(BEST_MODEL_PATH)

print("2️⃣  Configurando el convertidor TFLite...")
converter = tf.lite.TFLiteConverter.from_keras_model(model)

# Optimizaciones: 'DEFAULT' aplica cuantización dinámica (reduce tamaño x4 aprox sin perder mucha precisión)
converter.optimizations = [tf.lite.Optimize.DEFAULT]

print("3️⃣  Convirtiendo modelo (esto puede tardar unos segundos)...")
tflite_model = converter.convert()

# Definir ruta de salida
tflite_filename = "banano_efficientnetb0.tflite"
tflite_path = os.path.join(MODELS_DIR, tflite_filename)

# Guardar el archivo binario
with open(tflite_path, 'wb') as f:
    f.write(tflite_model)

print(f"✅ Modelo TFLite exportado exitosamente: {tflite_path}")

# ---------------------------------------------------------
# PASO 2: Guardar etiquetas (Labels)
# ---------------------------------------------------------
print("4️⃣  Generando archivo de etiquetas (labels.txt)...")
labels_path = os.path.join(MODELS_DIR, "labels.txt")

with open(labels_path, 'w') as f:
    for name in class_names:
        f.write(name + '\n')

print(f"✅ Etiquetas guardadas en: {labels_path}")

# ---------------------------------------------------------
# Verificación final para el desarrollador
# ---------------------------------------------------------
print("\n" + "="*50)
print("📌 INSTRUCCIONES PARA FLUTTER")
print("="*50)
print("1. Copia el archivo .tflite y labels.txt a la carpeta 'assets/' de tu proyecto Flutter.")
print("2. Asegúrate de que el orden de las clases sea EXACTAMENTE este:")
print("-" * 20)
for i, name in enumerate(class_names):
    print(f"[{i}] -> {name}")
print("-" * 20)
# Out:
# 📲 Preparando archivos para despliegue en móvil...
# 1️⃣  Cargando el mejor modelo guardado (.keras)...
# 2️⃣  Configurando el convertidor TFLite...
# 3️⃣  Convirtiendo modelo (esto puede tardar unos segundos)...
# Saved artifact at '/tmp/tmpleqoefkp'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 7), dtype=tf.float32, name=None)
# Captures:
#   136616217570064: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   136616217575248: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   136618214948688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136618214947728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136618214946960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136618214938896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136618214940624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136621222614544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136618214945040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136618362145104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136618214939856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136618214940432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136618214939088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136618362144144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136618362143184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136620939766736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136618214940816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136620939766160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136618214947344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136620939766928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136618214940240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136620939765776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650709328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650708944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136618362144336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136618214938704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650709136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650710288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650710096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650710672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650711248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650710480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650711632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650708560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650711056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650711440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650709904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650712208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650710864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650712976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650709712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650712400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650712784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650713360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650713936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650713168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650712592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650713744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650714320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650714896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650714128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650715280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650712016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615653259792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650715088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650713552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650716048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650714512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650716624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650716816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650716240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650715472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650717200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650717776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650716432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650714704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650717584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650718160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650718736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650717968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650719120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650717008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650718544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650718928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650717392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650719696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650718352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650720464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650711824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650719888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650720272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650720848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650721424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650720656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650719504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650721040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650720080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650721616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650721232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650715664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136615650719312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226260752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226260368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226260176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226259024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226259600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226261328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226261520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226260944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226260560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226261904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226262480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226261136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226259792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226262288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226262864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226263440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226262672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226263824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226261712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226263248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226263632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226262096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226264400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226263056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226265168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226259408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226264592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226264976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226265552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226266128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226265360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226264784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226265936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226266512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226267088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226266320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226267472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226264208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226266896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226267280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226265744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226268048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226266704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226268816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226269008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226268432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226267664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226269392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226269968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226268624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226268240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226269776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226270352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226270928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226270160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226271312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226269200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226270736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226271120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226269584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226271888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226270544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226272656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226272848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226272272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226271504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226273232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226273808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226272464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226272080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226273616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226274192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226274768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226274000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226271696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226264016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226274384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226274960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226274576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226275152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226273040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616226273424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215789840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215789648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215790416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215791184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215791760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215790992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215790608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215791568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215792144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215792720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215791952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215793104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215790224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215792528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215792912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215791376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215793680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215792336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215794448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215794640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215794064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215793296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215795024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215795600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215794256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215793872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215795408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215795984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215796560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215795792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215796944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215794832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215796368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215796752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215795216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215797520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215796176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215798288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215798480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215797904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215797136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215798864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215799440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215798096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215797712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215799248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215799824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215800400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215799632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215800784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215798672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215800208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215800592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215799056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215801360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215800016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215802128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215797328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215801552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215801936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215802512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215803088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215802320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215801744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215802896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215803472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215804048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215803280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215804432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215801168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215803856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215804240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215802704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215805008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215803664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215805776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215805392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215804816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215805200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215800976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215804624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616215805584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217560656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217560848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217560080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217559504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217559312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217561424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217560464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217559888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217561232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217559696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217562000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217561040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217562768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217562960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217562384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217561616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217563344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217563920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217562576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217562192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217563728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217564304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217564880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217564112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217565264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217563152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217564688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217565072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217563536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217565840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217564496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217566608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217566800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217566224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217565456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217567184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217567760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217566416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217566032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217567568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217568144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217568720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217567952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217569104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217566992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217568528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217568912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217567376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217569680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217568336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217570448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217565648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217569872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217570256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217570832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217571408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217571792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217571984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217571024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217571600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217572368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136616217572176: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ✅ Modelo TFLite exportado exitosamente: /content/drive/MyDrive/Entrenamiento con balanceo/EfficientNetB0/banano_efficientnetb0.tflite
# 4️⃣  Generando archivo de etiquetas (labels.txt)...
# ✅ Etiquetas guardadas en: /content/drive/MyDrive/Entrenamiento con balanceo/EfficientNetB0/labels.txt
#
# ==================================================
# 📌 INSTRUCCIONES PARA FLUTTER
# ==================================================
# 1. Copia el archivo .tflite y labels.txt a la carpeta 'assets/' de tu proyecto Flutter.
# 2. Asegúrate de que el orden de las clases sea EXACTAMENTE este:
# --------------------
# [0] -> apto
# [1] -> cascara_partida
# [2] -> cicatriz_golpe
# [3] -> corte_cuchareta
# [4] -> mal_formaciones
# [5] -> marca_madurez
# [6] -> plaga_enfermedades
# --------------------

# %% [markdown]
# 15. Análisis de Optimización: Comparativa de Pesos

# %%
import matplotlib.pyplot as plt
import os

# Configuración de rutas para guardar la gráfica
img_save_path = "/content/drive/MyDrive/Proyecto titulación/Models/img EfficientNetB0"
os.makedirs(img_save_path, exist_ok=True)

# Obtener tamaños de archivo en MB
keras_size = os.path.getsize(BEST_MODEL_PATH) / (1024 * 1024)
tflite_size = os.path.getsize(tflite_path) / (1024 * 1024)

# Datos para el gráfico
models_comparison = ['Keras (.keras)', 'TFLite (.tflite)']
sizes = [keras_size, tflite_size]
colors = ['#1f77b4', '#2ca02c']  # Azul y Verde

# ===== Gráfico de comparación de tamaños =====
plt.figure(figsize=(8, 6))
bars = plt.bar(models_comparison, sizes, color=colors, width=0.5)

plt.ylabel('Tamaño en MB', fontsize=12)
plt.title(f'Optimización de Modelo: EfficientNetB0\nReducción: {100 * (1 - tflite_size/keras_size):.1f}%', fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Añadir etiquetas de valor sobre las barras
for bar in bars:
    yval = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        yval + 0.2,
        f'{yval:.2f} MB',
        ha='center',
        va='bottom',
        fontsize=12,
        fontweight='bold'
    )

plt.tight_layout()

# Guardar la gráfica
output_chart_path = os.path.join(img_save_path, "model_size_comparison_efficientnetb0.png")
plt.savefig(output_chart_path, dpi=300, bbox_inches='tight')

print(f"📊 Gráfico de comparación guardado en: {output_chart_path}")
plt.show()
# Out:
# 📊 Gráfico de comparación guardado en: /content/drive/MyDrive/Proyecto titulación/Models/img EfficientNetB0/model_size_comparison_efficientnetb0.png
