# %% [markdown]
# 1. Importación de librerías

# %%
import os
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import (confusion_matrix, classification_report, accuracy_score,
                             precision_score, recall_score, f1_score, roc_auc_score)
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Ignorar warnings para limpieza del output
import warnings
warnings.filterwarnings('ignore')

print(f"TensorFlow Version: {tf.__version__}")
print(f"NumPy Version: {np.__version__}")
# Out:
# TensorFlow Version: 2.19.0
# NumPy Version: 2.0.2

# %% [markdown]
# 2. Configuración del entorno

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Semillas para reproducibilidad
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)

# Configuración de GPU
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"✅ GPU detectada: {len(gpus)} disponible(s)")
    except RuntimeError as e:
        print(e)
else:
    print("⚠️ No se detectó GPU. El entrenamiento será lento.")

# Parámetros Globales
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
CHANNELS = 3
INPUT_SHAPE = IMG_SIZE + (CHANNELS,)
NUM_EPOCHS_HEAD = 5    # Épocas fase 1 (cabeza)
NUM_EPOCHS_FINE = 15   # Épocas fase 2 (fine-tuning)

BASE_DIR = "/content/drive/MyDrive/Dataset" 
TRAIN_DIR = os.path.join(BASE_DIR, "Train")
VAL_DIR   = os.path.join(BASE_DIR, "Validation")
TEST_DIR  = os.path.join(BASE_DIR, "Test")
MODELS_DIR = "/content/drive/MyDrive/Entrenamiento con balanceo/ResNet50"
os.makedirs(MODELS_DIR, exist_ok=True)
BEST_MODEL_PATH = os.path.join(MODELS_DIR, "banano_ResNet50_best_scientific.keras")
# Out:
# ✅ GPU detectada: 1 disponible(s)

# %% [markdown]
# 3. Carga y exploración del dataset

# %%
# Carga de datasets usando image_dataset_from_directory
train_ds = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR,
    labels='inferred',
    label_mode='categorical',
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=SEED
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    VAL_DIR,
    labels='inferred',
    label_mode='categorical',
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False,
    seed=SEED
)

test_ds = tf.keras.utils.image_dataset_from_directory(
    TEST_DIR,
    labels='inferred',
    label_mode='categorical',
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False,
    seed=SEED
)

class_names = train_ds.class_names
num_classes = len(class_names)

print(f"\n🏷️ Clases detectadas ({num_classes}): {class_names}")

# Tabla de Support (Conteo de muestras)
def count_samples(directory, class_names):
    counts = []
    for cls in class_names:
        path = os.path.join(directory, cls)
        if os.path.exists(path):
            counts.append(len(os.listdir(path)))
        else:
            counts.append(0)
    return counts

train_counts = count_samples(TRAIN_DIR, class_names)
val_counts = count_samples(VAL_DIR, class_names)
test_counts = count_samples(TEST_DIR, class_names)

df_support = pd.DataFrame({
    'Clase': class_names,
    'Train Samples': train_counts,
    'Validation Samples': val_counts,
    'Test Samples': test_counts
})

# Gráfico de distribución
plt.figure(figsize=(12, 5))
x = np.arange(len(class_names))
width = 0.25
plt.bar(x - width, train_counts, width, label='Train', color='#1f77b4')
plt.bar(x, val_counts, width, label='Validation', color='#ff7f0e')
plt.bar(x + width, test_counts, width, label='Test', color='#2ca02c')
plt.xticks(x, class_names, rotation=45)
plt.ylabel('Número de imágenes')
plt.title('Distribución de Muestras por Clase')
plt.legend()
plt.tight_layout()
plt.show()

display(df_support)
# Out:
# Found 3500 files belonging to 7 classes.
# Found 350 files belonging to 7 classes.
# Found 350 files belonging to 7 classes.
#
# 🏷️ Clases detectadas (7): ['apto', 'cascara_partida', 'cicatriz_golpe', 'corte_cuchareta', 'mal_formaciones', 'marca_madurez', 'plaga_enfermedades']
#                 Clase  Train Samples  Validation Samples  Test Samples
# 0                apto            500                  50            50
# 1     cascara_partida            500                  50            50
# 2      cicatriz_golpe            500                  50            50
# 3     corte_cuchareta            500                  50            50
# 4     mal_formaciones            500                  50            50
# 5       marca_madurez            500                  50            50
# 6  plaga_enfermedades            500                  50            50

# %% [markdown]
# TABLA 1: DISTRIBUCIÓN POR CLASES DETALLADA

# %%
# ==========================================
# TABLA 1: DISTRIBUCIÓN POR CLASES DETALLADA
# ==========================================

# Calcular totales por clase
total_per_class = [t + v + te for t, v, te in zip(train_counts, val_counts, test_counts)]
total_dataset = sum(total_per_class)

# Calcular porcentajes
percentages = [f"{(count/total_dataset)*100:.2f}%" for count in total_per_class]

df_distribution = pd.DataFrame({
    'Clase (Etiqueta)': class_names,
    'Entrenamiento (Train)': train_counts,
    'Validación (Val)': val_counts,
    'Prueba (Test)': test_counts,
    'Total Muestras': total_per_class,
    'Distribución (%)': percentages
})

# Añadir fila de totales
row_total = pd.DataFrame({
    'Clase (Etiqueta)': ['TOTAL'],
    'Entrenamiento (Train)': [sum(train_counts)],
    'Validación (Val)': [sum(val_counts)],
    'Prueba (Test)': [sum(test_counts)],
    'Total Muestras': [total_dataset],
    'Distribución (%)': ['100%']
})

df_distribution = pd.concat([df_distribution, row_total], ignore_index=True)

print("\n📋 Tabla 1: Distribución del Dataset por Clases")
display(df_distribution)
# Out:
# 📋 Tabla 1: Distribución del Dataset por Clases
#      Clase (Etiqueta)  Entrenamiento (Train)  Validación (Val)  Prueba (Test)  \
# 0                apto                    500                50             50
# 1     cascara_partida                    500                50             50
# 2      cicatriz_golpe                    500                50             50
# 3     corte_cuchareta                    500                50             50
# 4     mal_formaciones                    500                50             50
# 5       marca_madurez                    500                50             50
# 6  plaga_enfermedades                    500                50             50
# 7               TOTAL                   3500               350            350
#
#    Total Muestras Distribución (%)
# 0             600           14.29%
# 1             600           14.29%
# 2             600           14.29%
# 3             600           14.29%
# 4             600           14.29%
# 5             600           14.29%
# 6             600           14.29%
# 7            4200             100%

# %% [markdown]
# 4. Preprocesamiento de datos

# %%
# Optimización de carga (Prefetching)
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)

# Capa de Data Augmentation dentro del modelo 
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
    layers.RandomTranslation(0.1, 0.1),
    layers.RandomContrast(0.1),
    layers.RandomBrightness(0.1)
], name="Data_Augmentation")

print("✅ Pipeline de datos configurado.")
# Out:
# ✅ Pipeline de datos configurado.

# %%
# ==================================================
# TABLA 2: TÉCNICAS DE PREPROCESAMIENTO APLICADAS
# ==================================================
preprocessing_data = [
    ["Redimensionamiento (Resize)", f"{IMG_SIZE[0]}x{IMG_SIZE[1]} píxeles", "Estandarización de entrada"],
    ["Espacio de Color", "RGB (3 canales)", "Formato estándar de imagen"],
    ["Normalización", "Interna (ResNet50)", "ResNet50 incluye capa de preprocesamiento (espera rangos [0-255])"],
    ["Batching", f"{BATCH_SIZE} imágenes por lote", "Optimización de memoria GPU"],
    ["Prefetching", "Autotune (Buffer dinámico)", "Carga asíncrona CPU-GPU"],
    ["Caching", "Memoria/Disco", "Evita recargar imágenes en cada época"]
]

df_preprocessing = pd.DataFrame(preprocessing_data, columns=["Técnica", "Configuración", "Justificación"])

print("\n🛠️ Tabla 2: Técnicas de Preprocesamiento")
display(df_preprocessing)


# ==================================================
# TABLA 3: TÉCNICAS DE AUMENTO DE DATOS (DATA AUGMENTATION)
# ==================================================
augmentation_data = [
    ["Random Flip", "Horizontal", "Simula espejo (izquierda/derecha)"],
    ["Random Rotation", "Factor 0.1 (±10%)", "Simula variaciones en el ángulo de captura"],
    ["Random Zoom", "Factor 0.1 (±10%)", "Simula distancia de la cámara"],
    ["Random Translation", "Height/Width 0.1", "Simula desplazamiento del objeto en el encuadre"],
    ["Random Contrast", "Factor 0.1", "Variabilidad en condiciones de iluminación"],
    ["Random Brightness", "Factor 0.1", "Variabilidad en exposición de luz"]
]

df_augmentation = pd.DataFrame(augmentation_data, columns=["Transformación", "Parámetros", "Objetivo"])

print("\n🔄 Tabla 3: Estrategia de Data Augmentation")
display(df_augmentation)
# Out:
# 🛠️ Tabla 2: Técnicas de Preprocesamiento
#                        Técnica               Configuración  \
# 0  Redimensionamiento (Resize)             224x224 píxeles
# 1             Espacio de Color             RGB (3 canales)
# 2                Normalización          Interna (ResNet50)
# 3                     Batching        32 imágenes por lote
# 4                  Prefetching  Autotune (Buffer dinámico)
# 5                      Caching               Memoria/Disco
#
#                                        Justificación
# 0                         Estandarización de entrada
# 1                         Formato estándar de imagen
# 2  ResNet50 incluye capa de preprocesamiento (esp...
# 3                        Optimización de memoria GPU
# 4                            Carga asíncrona CPU-GPU
# 5              Evita recargar imágenes en cada época
# 🔄 Tabla 3: Estrategia de Data Augmentation
#        Transformación         Parámetros  \
# 0         Random Flip         Horizontal
# 1     Random Rotation  Factor 0.1 (±10%)
# 2         Random Zoom  Factor 0.1 (±10%)
# 3  Random Translation   Height/Width 0.1
# 4     Random Contrast         Factor 0.1
# 5   Random Brightness         Factor 0.1
#
#                                           Objetivo
# 0                Simula espejo (izquierda/derecha)
# 1       Simula variaciones en el ángulo de captura
# 2                    Simula distancia de la cámara
# 3  Simula desplazamiento del objeto en el encuadre
# 4       Variabilidad en condiciones de iluminación
# 5                Variabilidad en exposición de luz

# %% [markdown]
# 5. Definición del modelo EfficientNetB0

# %%
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from keras.saving import register_keras_serializable
from tensorflow.keras import layers, models

# =========================================================
# 🔹 CAPA DE PREPROCESAMIENTO SERIALIZABLE PARA RESNET50
# =========================================================
@register_keras_serializable()
class ResNetPreprocess(layers.Layer):
    def call(self, inputs):
        return preprocess_input(inputs)


# =========================================================
# 🔹 FUNCIÓN PARA CONSTRUIR EL MODELO
# =========================================================
def build_model(num_classes, input_shape):

    inputs = layers.Input(shape=input_shape)

    # 1️⃣ Data Augmentation (igual que ya usas)
    x = data_augmentation(inputs)

    # 2️⃣ Preprocesamiento ResNet (IMPORTANTE)
    x = ResNetPreprocess(name="resnet50_preprocess")(x)

    # 3️⃣ Base Model ResNet50
    base_model = ResNet50(
        include_top=False,
        weights="imagenet",
        input_tensor=x
    )

    base_model.trainable = False  # 🔒 FASE 1

    # 4️⃣ Cabeza personalizada 
    x = layers.GlobalAveragePooling2D(name="avg_pool")(base_model.output)
    x = layers.BatchNormalization()(x)
    x = layers.Dense(512, activation='relu', name="fc1")(x)
    x = layers.Dropout(0.5, name="top_dropout")(x)

    # 5️⃣ Capa de salida
    outputs = layers.Dense(num_classes, activation='softmax', name="pred")(x)

    # 6️⃣ Modelo final
    model = models.Model(inputs, outputs, name="ResNet50_Banana_Classifier")

    return model, base_model


# Construcción
model, base_model = build_model(num_classes, INPUT_SHAPE)
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "ResNet50_Banana_Classifier"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Data_Augmentation   │ (None, 224, 224,  │          0 │ input_layer[0][0] │
# │ (Sequential)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ resnet50_preprocess │ (None, 224, 224,  │          0 │ Data_Augmentatio… │
# │ (ResNetPreprocess)  │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_pad           │ (None, 230, 230,  │          0 │ resnet50_preproc… │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_conv (Conv2D) │ (None, 112, 112,  │      9,472 │ conv1_pad[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_bn            │ (None, 112, 112,  │        256 │ conv1_conv[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_relu          │ (None, 112, 112,  │          0 │ conv1_bn[0][0]    │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pad           │ (None, 114, 114,  │          0 │ conv1_relu[0][0]  │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pool          │ (None, 56, 56,    │          0 │ pool1_pad[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_conv │ (None, 56, 56,    │      4,160 │ pool1_pool[0][0]  │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_bn   │ (None, 56, 56,    │        256 │ conv2_block1_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_relu │ (None, 56, 56,    │          0 │ conv2_block1_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_conv │ (None, 56, 56,    │     36,928 │ conv2_block1_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_bn   │ (None, 56, 56,    │        256 │ conv2_block1_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_relu │ (None, 56, 56,    │          0 │ conv2_block1_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_conv │ (None, 56, 56,    │     16,640 │ pool1_pool[0][0]  │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_3_conv │ (None, 56, 56,    │     16,640 │ conv2_block1_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_bn   │ (None, 56, 56,    │      1,024 │ conv2_block1_0_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_3_bn   │ (None, 56, 56,    │      1,024 │ conv2_block1_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_add    │ (None, 56, 56,    │          0 │ conv2_block1_0_b… │
# │ (Add)               │ 256)              │            │ conv2_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_out    │ (None, 56, 56,    │          0 │ conv2_block1_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_conv │ (None, 56, 56,    │     16,448 │ conv2_block1_out… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_bn   │ (None, 56, 56,    │        256 │ conv2_block2_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_relu │ (None, 56, 56,    │          0 │ conv2_block2_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_conv │ (None, 56, 56,    │     36,928 │ conv2_block2_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_bn   │ (None, 56, 56,    │        256 │ conv2_block2_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_relu │ (None, 56, 56,    │          0 │ conv2_block2_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_3_conv │ (None, 56, 56,    │     16,640 │ conv2_block2_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_3_bn   │ (None, 56, 56,    │      1,024 │ conv2_block2_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_add    │ (None, 56, 56,    │          0 │ conv2_block1_out… │
# │ (Add)               │ 256)              │            │ conv2_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_out    │ (None, 56, 56,    │          0 │ conv2_block2_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_conv │ (None, 56, 56,    │     16,448 │ conv2_block2_out… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_bn   │ (None, 56, 56,    │        256 │ conv2_block3_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_relu │ (None, 56, 56,    │          0 │ conv2_block3_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_conv │ (None, 56, 56,    │     36,928 │ conv2_block3_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_bn   │ (None, 56, 56,    │        256 │ conv2_block3_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_relu │ (None, 56, 56,    │          0 │ conv2_block3_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_3_conv │ (None, 56, 56,    │     16,640 │ conv2_block3_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_3_bn   │ (None, 56, 56,    │      1,024 │ conv2_block3_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_add    │ (None, 56, 56,    │          0 │ conv2_block2_out… │
# │ (Add)               │ 256)              │            │ conv2_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_out    │ (None, 56, 56,    │          0 │ conv2_block3_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_conv │ (None, 28, 28,    │     32,896 │ conv2_block3_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_bn   │ (None, 28, 28,    │        512 │ conv3_block1_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_relu │ (None, 28, 28,    │          0 │ conv3_block1_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_conv │ (None, 28, 28,    │    147,584 │ conv3_block1_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_bn   │ (None, 28, 28,    │        512 │ conv3_block1_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_relu │ (None, 28, 28,    │          0 │ conv3_block1_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_conv │ (None, 28, 28,    │    131,584 │ conv2_block3_out… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_3_conv │ (None, 28, 28,    │     66,048 │ conv3_block1_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_bn   │ (None, 28, 28,    │      2,048 │ conv3_block1_0_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_3_bn   │ (None, 28, 28,    │      2,048 │ conv3_block1_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_add    │ (None, 28, 28,    │          0 │ conv3_block1_0_b… │
# │ (Add)               │ 512)              │            │ conv3_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_out    │ (None, 28, 28,    │          0 │ conv3_block1_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_conv │ (None, 28, 28,    │     65,664 │ conv3_block1_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_bn   │ (None, 28, 28,    │        512 │ conv3_block2_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_relu │ (None, 28, 28,    │          0 │ conv3_block2_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_conv │ (None, 28, 28,    │    147,584 │ conv3_block2_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_bn   │ (None, 28, 28,    │        512 │ conv3_block2_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_relu │ (None, 28, 28,    │          0 │ conv3_block2_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_3_conv │ (None, 28, 28,    │     66,048 │ conv3_block2_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_3_bn   │ (None, 28, 28,    │      2,048 │ conv3_block2_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_add    │ (None, 28, 28,    │          0 │ conv3_block1_out… │
# │ (Add)               │ 512)              │            │ conv3_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_out    │ (None, 28, 28,    │          0 │ conv3_block2_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_conv │ (None, 28, 28,    │     65,664 │ conv3_block2_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_bn   │ (None, 28, 28,    │        512 │ conv3_block3_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_relu │ (None, 28, 28,    │          0 │ conv3_block3_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_conv │ (None, 28, 28,    │    147,584 │ conv3_block3_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_bn   │ (None, 28, 28,    │        512 │ conv3_block3_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_relu │ (None, 28, 28,    │          0 │ conv3_block3_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_3_conv │ (None, 28, 28,    │     66,048 │ conv3_block3_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_3_bn   │ (None, 28, 28,    │      2,048 │ conv3_block3_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_add    │ (None, 28, 28,    │          0 │ conv3_block2_out… │
# │ (Add)               │ 512)              │            │ conv3_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_out    │ (None, 28, 28,    │          0 │ conv3_block3_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_conv │ (None, 28, 28,    │     65,664 │ conv3_block3_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_bn   │ (None, 28, 28,    │        512 │ conv3_block4_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_relu │ (None, 28, 28,    │          0 │ conv3_block4_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_conv │ (None, 28, 28,    │    147,584 │ conv3_block4_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_bn   │ (None, 28, 28,    │        512 │ conv3_block4_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_relu │ (None, 28, 28,    │          0 │ conv3_block4_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_3_conv │ (None, 28, 28,    │     66,048 │ conv3_block4_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_3_bn   │ (None, 28, 28,    │      2,048 │ conv3_block4_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_add    │ (None, 28, 28,    │          0 │ conv3_block3_out… │
# │ (Add)               │ 512)              │            │ conv3_block4_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_out    │ (None, 28, 28,    │          0 │ conv3_block4_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_conv │ (None, 14, 14,    │    131,328 │ conv3_block4_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_bn   │ (None, 14, 14,    │      1,024 │ conv4_block1_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_relu │ (None, 14, 14,    │          0 │ conv4_block1_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_conv │ (None, 14, 14,    │    590,080 │ conv4_block1_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_bn   │ (None, 14, 14,    │      1,024 │ conv4_block1_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_relu │ (None, 14, 14,    │          0 │ conv4_block1_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_conv │ (None, 14, 14,    │    525,312 │ conv3_block4_out… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_3_conv │ (None, 14, 14,    │    263,168 │ conv4_block1_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_bn   │ (None, 14, 14,    │      4,096 │ conv4_block1_0_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_3_bn   │ (None, 14, 14,    │      4,096 │ conv4_block1_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_add    │ (None, 14, 14,    │          0 │ conv4_block1_0_b… │
# │ (Add)               │ 1024)             │            │ conv4_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_out    │ (None, 14, 14,    │          0 │ conv4_block1_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_conv │ (None, 14, 14,    │    262,400 │ conv4_block1_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_bn   │ (None, 14, 14,    │      1,024 │ conv4_block2_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_relu │ (None, 14, 14,    │          0 │ conv4_block2_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_conv │ (None, 14, 14,    │    590,080 │ conv4_block2_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_bn   │ (None, 14, 14,    │      1,024 │ conv4_block2_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_relu │ (None, 14, 14,    │          0 │ conv4_block2_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_3_conv │ (None, 14, 14,    │    263,168 │ conv4_block2_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_3_bn   │ (None, 14, 14,    │      4,096 │ conv4_block2_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_add    │ (None, 14, 14,    │          0 │ conv4_block1_out… │
# │ (Add)               │ 1024)             │            │ conv4_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_out    │ (None, 14, 14,    │          0 │ conv4_block2_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_conv │ (None, 14, 14,    │    262,400 │ conv4_block2_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_bn   │ (None, 14, 14,    │      1,024 │ conv4_block3_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_relu │ (None, 14, 14,    │          0 │ conv4_block3_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_conv │ (None, 14, 14,    │    590,080 │ conv4_block3_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_bn   │ (None, 14, 14,    │      1,024 │ conv4_block3_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_relu │ (None, 14, 14,    │          0 │ conv4_block3_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_3_conv │ (None, 14, 14,    │    263,168 │ conv4_block3_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_3_bn   │ (None, 14, 14,    │      4,096 │ conv4_block3_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_add    │ (None, 14, 14,    │          0 │ conv4_block2_out… │
# │ (Add)               │ 1024)             │            │ conv4_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_out    │ (None, 14, 14,    │          0 │ conv4_block3_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_conv │ (None, 14, 14,    │    262,400 │ conv4_block3_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_bn   │ (None, 14, 14,    │      1,024 │ conv4_block4_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_relu │ (None, 14, 14,    │          0 │ conv4_block4_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_conv │ (None, 14, 14,    │    590,080 │ conv4_block4_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_bn   │ (None, 14, 14,    │      1,024 │ conv4_block4_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_relu │ (None, 14, 14,    │          0 │ conv4_block4_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_3_conv │ (None, 14, 14,    │    263,168 │ conv4_block4_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_3_bn   │ (None, 14, 14,    │      4,096 │ conv4_block4_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_add    │ (None, 14, 14,    │          0 │ conv4_block3_out… │
# │ (Add)               │ 1024)             │            │ conv4_block4_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_out    │ (None, 14, 14,    │          0 │ conv4_block4_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_conv │ (None, 14, 14,    │    262,400 │ conv4_block4_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_bn   │ (None, 14, 14,    │      1,024 │ conv4_block5_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_relu │ (None, 14, 14,    │          0 │ conv4_block5_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_conv │ (None, 14, 14,    │    590,080 │ conv4_block5_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_bn   │ (None, 14, 14,    │      1,024 │ conv4_block5_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_relu │ (None, 14, 14,    │          0 │ conv4_block5_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_3_conv │ (None, 14, 14,    │    263,168 │ conv4_block5_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_3_bn   │ (None, 14, 14,    │      4,096 │ conv4_block5_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_add    │ (None, 14, 14,    │          0 │ conv4_block4_out… │
# │ (Add)               │ 1024)             │            │ conv4_block5_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_out    │ (None, 14, 14,    │          0 │ conv4_block5_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_conv │ (None, 14, 14,    │    262,400 │ conv4_block5_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_bn   │ (None, 14, 14,    │      1,024 │ conv4_block6_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_relu │ (None, 14, 14,    │          0 │ conv4_block6_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_conv │ (None, 14, 14,    │    590,080 │ conv4_block6_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_bn   │ (None, 14, 14,    │      1,024 │ conv4_block6_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_relu │ (None, 14, 14,    │          0 │ conv4_block6_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_3_conv │ (None, 14, 14,    │    263,168 │ conv4_block6_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_3_bn   │ (None, 14, 14,    │      4,096 │ conv4_block6_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_add    │ (None, 14, 14,    │          0 │ conv4_block5_out… │
# │ (Add)               │ 1024)             │            │ conv4_block6_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_out    │ (None, 14, 14,    │          0 │ conv4_block6_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_conv │ (None, 7, 7, 512) │    524,800 │ conv4_block6_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block1_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_relu │ (None, 7, 7, 512) │          0 │ conv5_block1_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_conv │ (None, 7, 7, 512) │  2,359,808 │ conv5_block1_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block1_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_relu │ (None, 7, 7, 512) │          0 │ conv5_block1_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_0_conv │ (None, 7, 7,      │  2,099,200 │ conv4_block6_out… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_3_conv │ (None, 7, 7,      │  1,050,624 │ conv5_block1_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_0_bn   │ (None, 7, 7,      │      8,192 │ conv5_block1_0_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_3_bn   │ (None, 7, 7,      │      8,192 │ conv5_block1_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_add    │ (None, 7, 7,      │          0 │ conv5_block1_0_b… │
# │ (Add)               │ 2048)             │            │ conv5_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_out    │ (None, 7, 7,      │          0 │ conv5_block1_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_conv │ (None, 7, 7, 512) │  1,049,088 │ conv5_block1_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block2_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_relu │ (None, 7, 7, 512) │          0 │ conv5_block2_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_conv │ (None, 7, 7, 512) │  2,359,808 │ conv5_block2_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block2_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_relu │ (None, 7, 7, 512) │          0 │ conv5_block2_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_3_conv │ (None, 7, 7,      │  1,050,624 │ conv5_block2_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_3_bn   │ (None, 7, 7,      │      8,192 │ conv5_block2_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_add    │ (None, 7, 7,      │          0 │ conv5_block1_out… │
# │ (Add)               │ 2048)             │            │ conv5_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_out    │ (None, 7, 7,      │          0 │ conv5_block2_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_conv │ (None, 7, 7, 512) │  1,049,088 │ conv5_block2_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block3_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_relu │ (None, 7, 7, 512) │          0 │ conv5_block3_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_conv │ (None, 7, 7, 512) │  2,359,808 │ conv5_block3_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block3_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_relu │ (None, 7, 7, 512) │          0 │ conv5_block3_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_3_conv │ (None, 7, 7,      │  1,050,624 │ conv5_block3_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_3_bn   │ (None, 7, 7,      │      8,192 │ conv5_block3_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_add    │ (None, 7, 7,      │          0 │ conv5_block2_out… │
# │ (Add)               │ 2048)             │            │ conv5_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_out    │ (None, 7, 7,      │          0 │ conv5_block3_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ avg_pool            │ (None, 2048)      │          0 │ conv5_block3_out… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 2048)      │      8,192 │ avg_pool[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fc1 (Dense)         │ (None, 512)       │  1,049,088 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_dropout         │ (None, 512)       │          0 │ fc1[0][0]         │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pred (Dense)        │ (None, 7)         │      3,591 │ top_dropout[0][0] │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 24,648,583 (94.03 MB)
#  Trainable params: 1,056,775 (4.03 MB)
#  Non-trainable params: 23,591,808 (90.00 MB)

# %% [markdown]
# 6. Configuración del entrenamiento

# %%
# Tabla de configuración
config_df = pd.DataFrame({
    'Parámetro': ['Optimizer', 'Loss Function', 'Batch Size', 'Img Size', 'Base Trainable (Fase 1)'],
    'Valor': ['Adam', 'Categorical Crossentropy', BATCH_SIZE, IMG_SIZE, 'False']
})
display(config_df)

# Callbacks
callbacks = [
    ModelCheckpoint(BEST_MODEL_PATH, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1),
    EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, min_lr=1e-6, verbose=1)
]

# Compilación Fase 1
model.compile(
    optimizer=optimizers.Adam(learning_rate=1e-3),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
#                  Parámetro                     Valor
# 0                Optimizer                      Adam
# 1            Loss Function  Categorical Crossentropy
# 2               Batch Size                        32
# 3                 Img Size                (224, 224)
# 4  Base Trainable (Fase 1)                     False

# %% [markdown]
# TABLA 4: CONFIGURACIÓN DE HIPERPARÁMETROS

# %%
# ==========================================
# TABLA 4: CONFIGURACIÓN DE HIPERPARÁMETROS
# ==========================================

training_config = [
    ["Arquitectura Base", "ResNet50", "Pre-entrenada en ImageNet"],
    ["Pesos Iniciales", "ImageNet", "Transfer Learning"],
    ["Input Shape", f"{INPUT_SHAPE}", "Resolución 224x224x3"],
    ["Optimizador", "Adam", "Algoritmo adaptativo"],
    ["Loss Function", "Categorical Crossentropy", "Para clasificación multiclase one-hot"],
    ["Learning Rate (Fase 1)", "0.001 (1e-3)", "Entrenamiento rápido de la cabeza"],
    ["Learning Rate (Fase 2)", "0.00001 (1e-5)", "Fine-Tuning lento y preciso"],
    ["Batch Size", f"{BATCH_SIZE}", "Balance entre velocidad y memoria"],
    ["Épocas Fase 1 (Head)", f"{NUM_EPOCHS_HEAD}", "Adaptación de nuevas clases"],
    ["Épocas Fase 2 (Fine-Tune)", f"{NUM_EPOCHS_FINE}", "Ajuste fino de pesos profundos"],
    ["Dropout", "0.3 (30%)", "Prevención de Overfitting en capa densa"],
    ["Early Stopping", "Patience=5", "Detiene si no mejora val_accuracy"]
]

df_config = pd.DataFrame(training_config, columns=["Hiperparámetro / Configuración", "Valor", "Descripción"])

print("\n⚙️ Tabla 4: Configuración del Experimento")
display(df_config)
# Out:
# ⚙️ Tabla 4: Configuración del Experimento
#    Hiperparámetro / Configuración                     Valor  \
# 0               Arquitectura Base                  ResNet50
# 1                 Pesos Iniciales                  ImageNet
# 2                     Input Shape             (224, 224, 3)
# 3                     Optimizador                      Adam
# 4                   Loss Function  Categorical Crossentropy
# 5          Learning Rate (Fase 1)              0.001 (1e-3)
# 6          Learning Rate (Fase 2)            0.00001 (1e-5)
# 7                      Batch Size                        32
# 8            Épocas Fase 1 (Head)                         5
# 9       Épocas Fase 2 (Fine-Tune)                        15
# 10                        Dropout                 0.3 (30%)
# 11                 Early Stopping                Patience=5
#
#                                 Descripción
# 0                 Pre-entrenada en ImageNet
# 1                         Transfer Learning
# 2                      Resolución 224x224x3
# 3                      Algoritmo adaptativo
# 4     Para clasificación multiclase one-hot
# 5         Entrenamiento rápido de la cabeza
# 6               Fine-Tuning lento y preciso
# 7         Balance entre velocidad y memoria
# 8               Adaptación de nuevas clases
# 9            Ajuste fino de pesos profundos
# 10  Prevención de Overfitting en capa densa
# 11        Detiene si no mejora val_accuracy

# %% [markdown]
# 7. Entrenamiento del modelo

# %%
# --- FASE 1: Feature Extraction ---
print(f"\n🚀 Iniciando Fase 1: Entrenamiento de la cabeza ({NUM_EPOCHS_HEAD} épocas)...")
start_time = time.time()

history_1 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=NUM_EPOCHS_HEAD,
    callbacks=callbacks
)

phase1_time = time.time() - start_time

# --- FASE 2: Fine-Tuning ---
print(f"\n🔓 Descongelando últimas capas de ResNet50...")

base_model.trainable = True

# Solo desbloqueamos los últimos bloques convolucionales

for layer in base_model.layers:
    if "conv5" in layer.name:  
        layer.trainable = True
    else:
        layer.trainable = False

model.compile(
    optimizer=optimizers.Adam(learning_rate=1e-5),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

print(f"🚀 Iniciando Fase 2: Fine-Tuning ({NUM_EPOCHS_FINE} épocas)...")
start_time_2 = time.time()

# Ajustamos epoch inicial para que la gráfica sea continua
history_2 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=NUM_EPOCHS_HEAD + NUM_EPOCHS_FINE,
    initial_epoch=history_1.epoch[-1] + 1,
    callbacks=callbacks
)

phase2_time = time.time() - start_time_2

# Tabla de tiempos
time_df = pd.DataFrame({
    'Fase': ['Feature Extraction', 'Fine-Tuning', 'Total'],
    'Tiempo (min)': [phase1_time/60, phase2_time/60, (phase1_time+phase2_time)/60]
})
display(time_df)
# Out:
# 🚀 Iniciando Fase 1: Entrenamiento de la cabeza (5 épocas)...
# Epoch 1/5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.6834 - loss: 1.1025
# Epoch 1: val_accuracy improved from -inf to 0.82857, saving model to /content/drive/MyDrive/Entrenamiento con balanceo/ResNet50/banano_ResNet50_best_scientific.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1076s 10s/step - accuracy: 0.6843 - loss: 1.0996 - val_accuracy: 0.8286 - val_loss: 0.4918 - learning_rate: 0.0010
# Epoch 2/5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.8979 - loss: 0.3252
# Epoch 2: val_accuracy improved from 0.82857 to 0.93143, saving model to /content/drive/MyDrive/Entrenamiento con balanceo/ResNet50/banano_ResNet50_best_scientific.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 18s 163ms/step - accuracy: 0.8979 - loss: 0.3252 - val_accuracy: 0.9314 - val_loss: 0.2174 - learning_rate: 0.0010
# Epoch 3/5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9228 - loss: 0.2671
# Epoch 3: val_accuracy improved from 0.93143 to 0.95429, saving model to /content/drive/MyDrive/Entrenamiento con balanceo/ResNet50/banano_ResNet50_best_scientific.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 18s 163ms/step - accuracy: 0.9228 - loss: 0.2667 - val_accuracy: 0.9543 - val_loss: 0.1193 - learning_rate: 0.0010
# Epoch 4/5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9475 - loss: 0.1723
# Epoch 4: val_accuracy did not improve from 0.95429
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 16s 150ms/step - accuracy: 0.9475 - loss: 0.1725 - val_accuracy: 0.9543 - val_loss: 0.2037 - learning_rate: 0.0010
# Epoch 5/5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9503 - loss: 0.1582
# Epoch 5: val_accuracy did not improve from 0.95429
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 16s 148ms/step - accuracy: 0.9503 - loss: 0.1583 - val_accuracy: 0.9514 - val_loss: 0.2037 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 3.
#
# 🔓 Descongelando últimas capas de ResNet50...
# 🚀 Iniciando Fase 2: Fine-Tuning (15 épocas)...
# Epoch 6/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9190 - loss: 0.2372
# Epoch 6: val_accuracy did not improve from 0.95429
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 39s 230ms/step - accuracy: 0.9190 - loss: 0.2373 - val_accuracy: 0.9314 - val_loss: 0.2347 - learning_rate: 1.0000e-05
# Epoch 7/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.9493 - loss: 0.1478
# Epoch 7: val_accuracy did not improve from 0.95429
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 23s 210ms/step - accuracy: 0.9493 - loss: 0.1477 - val_accuracy: 0.9343 - val_loss: 0.1902 - learning_rate: 1.0000e-05
# Epoch 8/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9627 - loss: 0.1250
# Epoch 8: val_accuracy did not improve from 0.95429
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 23s 206ms/step - accuracy: 0.9627 - loss: 0.1249 - val_accuracy: 0.9371 - val_loss: 0.1936 - learning_rate: 1.0000e-05
# Epoch 9/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.9717 - loss: 0.0887
# Epoch 9: val_accuracy did not improve from 0.95429
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 22s 204ms/step - accuracy: 0.9717 - loss: 0.0887 - val_accuracy: 0.9457 - val_loss: 0.1693 - learning_rate: 1.0000e-05
# Epoch 10/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9701 - loss: 0.0819
# Epoch 10: val_accuracy did not improve from 0.95429
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 23s 206ms/step - accuracy: 0.9701 - loss: 0.0818 - val_accuracy: 0.9514 - val_loss: 0.1563 - learning_rate: 1.0000e-05
# Epoch 11/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9786 - loss: 0.0615
# Epoch 11: val_accuracy did not improve from 0.95429
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 23s 207ms/step - accuracy: 0.9786 - loss: 0.0615 - val_accuracy: 0.9543 - val_loss: 0.1580 - learning_rate: 1.0000e-05
# Epoch 12/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9822 - loss: 0.0538
# Epoch 12: val_accuracy improved from 0.95429 to 0.96286, saving model to /content/drive/MyDrive/Entrenamiento con balanceo/ResNet50/banano_ResNet50_best_scientific.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 24s 223ms/step - accuracy: 0.9822 - loss: 0.0538 - val_accuracy: 0.9629 - val_loss: 0.1154 - learning_rate: 1.0000e-05
# Epoch 13/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9846 - loss: 0.0473
# Epoch 13: val_accuracy improved from 0.96286 to 0.97143, saving model to /content/drive/MyDrive/Entrenamiento con balanceo/ResNet50/banano_ResNet50_best_scientific.keras
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 43s 238ms/step - accuracy: 0.9846 - loss: 0.0473 - val_accuracy: 0.9714 - val_loss: 0.1045 - learning_rate: 1.0000e-05
# Epoch 14/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.9849 - loss: 0.0414
# Epoch 14: val_accuracy did not improve from 0.97143
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 23s 212ms/step - accuracy: 0.9849 - loss: 0.0414 - val_accuracy: 0.9629 - val_loss: 0.1325 - learning_rate: 1.0000e-05
# Epoch 15/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9896 - loss: 0.0324
# Epoch 15: val_accuracy did not improve from 0.97143
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 22s 204ms/step - accuracy: 0.9895 - loss: 0.0325 - val_accuracy: 0.9629 - val_loss: 0.1097 - learning_rate: 1.0000e-05
# Epoch 16/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9864 - loss: 0.0384
# Epoch 16: val_accuracy did not improve from 0.97143
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 22s 204ms/step - accuracy: 0.9864 - loss: 0.0384 - val_accuracy: 0.9686 - val_loss: 0.0944 - learning_rate: 5.0000e-06
# Epoch 17/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9893 - loss: 0.0267
# Epoch 17: val_accuracy did not improve from 0.97143
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 23s 205ms/step - accuracy: 0.9893 - loss: 0.0268 - val_accuracy: 0.9629 - val_loss: 0.0907 - learning_rate: 5.0000e-06
# Epoch 18/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9927 - loss: 0.0269
# Epoch 18: val_accuracy did not improve from 0.97143
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 23s 205ms/step - accuracy: 0.9927 - loss: 0.0269 - val_accuracy: 0.9714 - val_loss: 0.0862 - learning_rate: 5.0000e-06
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 13.
#                  Fase  Tiempo (min)
# 0  Feature Extraction     19.076478
# 1         Fine-Tuning      5.549562
# 2               Total     24.626039

# %% [markdown]
# 8. Curvas de aprendizaje

# %%
def plot_training_history(h1, h2):
    acc = h1.history['accuracy'] + h2.history['accuracy']
    val_acc = h1.history['val_accuracy'] + h2.history['val_accuracy']
    loss = h1.history['loss'] + h2.history['loss']
    val_loss = h1.history['val_loss'] + h2.history['val_loss']

    epochs_range = range(len(acc))

    plt.figure(figsize=(14, 6))

    # Accuracy
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.axvline(x=len(h1.history['accuracy'])-1, color='green', linestyle='--', label='Inicio Fine-Tuning')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.grid(True)

    # Loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.axvline(x=len(h1.history['loss'])-1, color='green', linestyle='--', label='Inicio Fine-Tuning')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.grid(True)

    plt.show()

plot_training_history(history_1, history_2)

# %% [markdown]
# 9. Evaluación del modelo (Cálculo de métricas detalladas)

# %%
print("\n🧪 Evaluando modelo en Test Set...")

# Obtener etiquetas verdaderas y predicciones
y_true = []
y_pred_probs = []

# Iterar sobre el dataset de test 
for images, labels in test_ds:
    y_true.extend(np.argmax(labels.numpy(), axis=1))
    preds = model.predict(images, verbose=0)
    y_pred_probs.extend(preds)

y_true = np.array(y_true)
y_pred_probs = np.array(y_pred_probs)
y_pred = np.argmax(y_pred_probs, axis=1)

# Cálculo de métricas One-vs-All por clase
metrics_list = []

for i, class_name in enumerate(class_names):
    # Crear etiquetas binarias para la clase actual vs resto
    y_true_cls = (y_true == i).astype(int)
    y_pred_cls = (y_pred == i).astype(int)

    # Matriz de confusión binaria
    tn, fp, fn, tp = confusion_matrix(y_true_cls, y_pred_cls).ravel()

    # Métricas
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    precision = tp / (tp + fp) if (tp + fp) > 0 else 0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0 
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0 
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
    fpr = fp / (tn + fp) if (tn + fp) > 0 else 0
    youden = recall + specificity - 1

    # AUC One-vs-Rest
    try:
        auc = roc_auc_score(y_true_cls, y_pred_probs[:, i])
    except ValueError:
        auc = 0.0

    support = tp + fn

    metrics_list.append({
        'Class': class_name,
        'Accuracy': accuracy,
        'Precision': precision,
        'Recall (Sens)': recall,
        'Specificity': specificity,
        'F1-Score': f1,
        'AUC': auc,
        'Youden Index': youden,
        'FPR': fpr,
        'TP': tp, 'TN': tn, 'FP': fp, 'FN': fn,
        'Support': support
    })

metrics_df = pd.DataFrame(metrics_list)
# Out:
# 🧪 Evaluando modelo en Test Set...

# %% [markdown]
# 10. Matriz de Confusión

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.ylabel('Etiqueta Verdadera')
plt.xlabel('Etiqueta Predicha')
plt.title('Matriz de Confusión - ResNet50')
plt.show()

# %% [markdown]
# 11. Tablas de métricas

# %%
# 11.1 Tabla por Clase
print("\n📊 Métricas Detalladas por Clase:")
display(metrics_df.round(4))

# 11.2 Métricas Globales (Weighted Average)
global_metrics = {
    'Global Accuracy': accuracy_score(y_true, y_pred),
    'Weighted Precision': precision_score(y_true, y_pred, average='weighted'),
    'Weighted Recall': recall_score(y_true, y_pred, average='weighted'),
    'Weighted F1': f1_score(y_true, y_pred, average='weighted'),
    'Macro Recall': recall_score(y_true, y_pred, average='macro'),
    'Macro AUC': roc_auc_score(y_true, y_pred_probs, multi_class='ovr', average='macro')
}

global_df = pd.DataFrame([global_metrics])
print("\n🌍 Métricas Globales:")
display(global_df.round(4))
# Out:
# 📊 Métricas Detalladas por Clase:
#                 Class  Accuracy  Precision  Recall (Sens)  Specificity  \
# 0                apto    1.0000     1.0000           1.00       1.0000
# 1     cascara_partida    0.9943     0.9615           1.00       0.9933
# 2      cicatriz_golpe    0.9857     1.0000           0.90       1.0000
# 3     corte_cuchareta    1.0000     1.0000           1.00       1.0000
# 4     mal_formaciones    0.9943     0.9615           1.00       0.9933
# 5       marca_madurez    0.9914     0.9608           0.98       0.9933
# 6  plaga_enfermedades    1.0000     1.0000           1.00       1.0000
#
#    F1-Score     AUC  Youden Index     FPR  TP   TN  FP  FN  Support
# 0    1.0000  1.0000        1.0000  0.0000  50  300   0   0       50
# 1    0.9804  0.9996        0.9933  0.0067  50  298   2   0       50
# 2    0.9474  1.0000        0.9000  0.0000  45  300   0   5       50
# 3    1.0000  1.0000        1.0000  0.0000  50  300   0   0       50
# 4    0.9804  0.9999        0.9933  0.0067  50  298   2   0       50
# 5    0.9703  0.9995        0.9733  0.0067  49  298   2   1       50
# 6    1.0000  1.0000        1.0000  0.0000  50  300   0   0       50
# 🌍 Métricas Globales:
#    Global Accuracy  Weighted Precision  Weighted Recall  Weighted F1  \
# 0           0.9829              0.9834           0.9829       0.9826
#
#    Macro Recall  Macro AUC
# 0        0.9829     0.9999

# %% [markdown]
# 12. Evaluación del mejor modelo

# %%
print(f"\n🏆 Cargando el mejor modelo guardado desde: {BEST_MODEL_PATH}")
try:
    best_model = tf.keras.models.load_model(BEST_MODEL_PATH)

    # Evaluación rápida del mejor modelo
    loss, acc = best_model.evaluate(test_ds, verbose=0)
    print(f"Best Model Test Accuracy: {acc:.4f}")
    print(f"Best Model Test Loss: {loss:.4f}")

    # Comprobación de selección
    if acc > global_metrics['Global Accuracy']:
        print("✅ El modelo guardado es mejor que el modelo final en memoria.")
    else:
        print("ℹ️ El modelo en memoria tiene un rendimiento similar o igual.")

except Exception as e:
    print(f"Error cargando el modelo: {e}")
# Out:
# 🏆 Cargando el mejor modelo guardado desde: /content/drive/MyDrive/Entrenamiento con balanceo/ResNet50/banano_ResNet50_best_scientific.keras
# Best Model Test Accuracy: 0.9829
# Best Model Test Loss: 0.0653
# ✅ El modelo guardado es mejor que el modelo final en memoria.

# %% [markdown]
# 13. Resultados finales y Conclusiones

# %%
# Generar reporte de texto estándar de scikit-learn para complementar
print("\n📝 Classification Report (Scikit-Learn Standard):")
print(classification_report(y_true, y_pred, target_names=class_names))

# Análisis de resultados (Markdown generado dinámicamente)
best_class = metrics_df.loc[metrics_df['F1-Score'].idxmax()]
worst_class = metrics_df.loc[metrics_df['F1-Score'].idxmin()]

print("="*50)
print("CONCLUSIONES DEL EXPERIMENTO")
print("="*50)
print(f"1. Rendimiento Global: El modelo alcanzó una exactitud (Top-1 Accuracy) del {global_metrics['Global Accuracy']:.2%}.")
print(f"2. Mejor Clase: '{best_class['Class']}' con un F1-Score de {best_class['F1-Score']:.4f}.")
print(f"3. Peor Clase: '{worst_class['Class']}' con un F1-Score de {worst_class['F1-Score']:.4f}. (Posible confusión visual).")
print(f"4. Discriminación: El AUC promedio es {global_metrics['Macro AUC']:.4f}, indicando una { 'excelente' if global_metrics['Macro AUC'] > 0.9 else 'buena' } capacidad de separación entre clases.")
print(f"5. Tiempos: El entrenamiento total tomó aproximadamente {(phase1_time+phase2_time)/60:.1f} minutos.")
print("="*50)
# Out:
# 📝 Classification Report (Scikit-Learn Standard):
#                     precision    recall  f1-score   support
#
#               apto       1.00      1.00      1.00        50
#    cascara_partida       0.96      1.00      0.98        50
#     cicatriz_golpe       1.00      0.90      0.95        50
#    corte_cuchareta       1.00      1.00      1.00        50
#    mal_formaciones       0.96      1.00      0.98        50
#      marca_madurez       0.96      0.98      0.97        50
# plaga_enfermedades       1.00      1.00      1.00        50
#
#           accuracy                           0.98       350
#          macro avg       0.98      0.98      0.98       350
#       weighted avg       0.98      0.98      0.98       350
#
# ==================================================
# CONCLUSIONES DEL EXPERIMENTO
# ==================================================
# 1. Rendimiento Global: El modelo alcanzó una exactitud (Top-1 Accuracy) del 98.29%.
# 2. Mejor Clase: 'apto' con un F1-Score de 1.0000.
# 3. Peor Clase: 'cicatriz_golpe' con un F1-Score de 0.9474. (Posible confusión visual).
# 4. Discriminación: El AUC promedio es 0.9999, indicando una excelente capacidad de separación entre clases.
# 5. Tiempos: El entrenamiento total tomó aproximadamente 24.6 minutos.
# ==================================================

# %% [markdown]
# 14. EXPORTACIÓN DEL MODELO Y ETIQUETAS (DEPLOYMENT)

# %%
import tensorflow as tf
import os

# =========================================================
# 14. EXPORTACIÓN DEL MODELO Y ETIQUETAS (DEPLOYMENT)
# =========================================================

print(f"\n📲 Preparando archivos para despliegue en móvil...")

# ---------------------------------------------------------
# PASO 1: Convertir el modelo .keras a .tflite
# ---------------------------------------------------------
print("1️⃣  Cargando el mejor modelo guardado (.keras)...")

if not os.path.exists(BEST_MODEL_PATH):
    raise FileNotFoundError(f"❌ No se encontró el modelo en: {BEST_MODEL_PATH}")

model = tf.keras.models.load_model(BEST_MODEL_PATH)

print("2️⃣  Configurando el convertidor TFLite...")
converter = tf.lite.TFLiteConverter.from_keras_model(model)

converter.optimizations = [tf.lite.Optimize.DEFAULT]

print("3️⃣  Convirtiendo modelo (esto puede tardar unos segundos)...")
tflite_model = converter.convert()

# Definir ruta de salida
tflite_filename = "banano_ResNet50.tflite"
tflite_path = os.path.join(MODELS_DIR, tflite_filename)

# Guardar el archivo binario
with open(tflite_path, 'wb') as f:
    f.write(tflite_model)

print(f"✅ Modelo TFLite exportado exitosamente: {tflite_path}")

# ---------------------------------------------------------
# PASO 2: Guardar etiquetas (Labels)
# ---------------------------------------------------------
print("4️⃣  Generando archivo de etiquetas (labels.txt)...")
labels_path = os.path.join(MODELS_DIR, "labels.txt")

with open(labels_path, 'w') as f:
    for name in class_names:
        f.write(name + '\n')

print(f"✅ Etiquetas guardadas en: {labels_path}")

# ---------------------------------------------------------
# Verificación final para el desarrollador
# ---------------------------------------------------------
print("\n" + "="*50)
print("📌 INSTRUCCIONES PARA FLUTTER")
print("="*50)
print("1. Copia el archivo .tflite y labels.txt a la carpeta 'assets/' de tu proyecto Flutter.")
print("2. Asegúrate de que el orden de las clases sea EXACTAMENTE este:")
print("-" * 20)
for i, name in enumerate(class_names):
    print(f"[{i}] -> {name}")
print("-" * 20)
# Out:
# 📲 Preparando archivos para despliegue en móvil...
# 1️⃣  Cargando el mejor modelo guardado (.keras)...
# 2️⃣  Configurando el convertidor TFLite...
# 3️⃣  Convirtiendo modelo (esto puede tardar unos segundos)...
# Saved artifact at '/tmp/tmp6yre6cn2'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 7), dtype=tf.float32, name=None)
# Captures:
#   132786308580560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308581328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308581712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308582672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308582480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308581904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308582288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308581520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308580752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308583824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308583632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308581136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308583440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308582864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308580944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308584976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308584784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308583056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308585744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308585168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308584592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308584016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308583248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308586512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308586320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308585360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308587088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308587280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308586704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308586896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308586128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308585936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308584400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308588432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308588240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308584208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308588048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308587472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308585552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308589584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308589392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308587664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308589200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308588624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308582096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308590736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308590544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308588816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308590352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308589776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308587856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308591888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308591696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308589968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308591504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308590928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308589008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308593040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308592848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308591120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308592656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308592080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308590160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308594192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308594000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308592272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308593808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308593232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308591312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308595344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308595152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308593424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308594960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308594576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308592464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308595536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308593616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308594768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307532368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307530832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308594384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307531408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307531216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307533136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307532944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307531024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307533712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307533904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307533328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307533520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307532752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307532560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307531600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307535056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307534864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307531984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307534672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307534096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307532176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307536208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307536016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307534288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786706463248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307535248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307531792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307537360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307537168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307535440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307536976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307535824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307534480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307538512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307538320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307536592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307538128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307537552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307536400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307539664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307539472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307537744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307539280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307538704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307536784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307540816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307540624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307538896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307540432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307539856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307537936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307541968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307541776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307540048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307541584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307541008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307539088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307543120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307542928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307541200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307542736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307542160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307540240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307544272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307544080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307542352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307543888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307543312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307541392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307545424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307545232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307543504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307545040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307544464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307542544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307546576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307546384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307544656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307545616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307544848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307546192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307545808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307546768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307543696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307546000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307546960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308367952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308368144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308366800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308367760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308367376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308366992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308366608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308369296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308369104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308366416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308368912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308368336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308367184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308370448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308370256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308368528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308370064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308369488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308367568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308371600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308371408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308369680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308371216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308370640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308368720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308372752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308372560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308370832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308372368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308371792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308369872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308373904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308373712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308371984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308373520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308372944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308371024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308375056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308374864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308373136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308374672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308374096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308372176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308376208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308376016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308374288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308375824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308375248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308373328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308377360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308377168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308375440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308376976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308376400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308374480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308378512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308378320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308376592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308378128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308377552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308375632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308379664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308379472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308377744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308379280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308378704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308376784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308380816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308380624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308378896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308380432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308379856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308377936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308381968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308381776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308380048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308381584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308382544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308382160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308381008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308380240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308381200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308382352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308381392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307106192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307106384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786308379088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307105232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307104848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307105616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307105808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307107536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307107344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307106000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307107152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307106576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307105424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307108688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307108496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307106768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307108304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307107728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307105040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307109840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307109648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307107920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307110608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307110032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307109456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307108880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307108112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307111376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307111184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307110224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307111952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307112144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307111568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307111760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307110992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307110800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307109264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307113296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307113104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307109072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307112912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307112336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307110416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307114448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307114256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307112528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307114064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307113488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307106960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307115600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307115408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307113680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307115216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307114640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307112720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307116752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307116560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307114832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307116368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307115792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307113872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307117904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307117712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307115984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307117520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307116944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307115024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307119056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307118864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307117136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307119632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307119824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307119248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307119440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307118672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307118096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307118288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132786307120976: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ✅ Modelo TFLite exportado exitosamente: /content/drive/MyDrive/Entrenamiento con balanceo/ResNet50/banano_ResNet50.tflite
# 4️⃣  Generando archivo de etiquetas (labels.txt)...
# ✅ Etiquetas guardadas en: /content/drive/MyDrive/Entrenamiento con balanceo/ResNet50/labels.txt
#
# ==================================================
# 📌 INSTRUCCIONES PARA FLUTTER
# ==================================================
# 1. Copia el archivo .tflite y labels.txt a la carpeta 'assets/' de tu proyecto Flutter.
# 2. Asegúrate de que el orden de las clases sea EXACTAMENTE este:
# --------------------
# [0] -> apto
# [1] -> cascara_partida
# [2] -> cicatriz_golpe
# [3] -> corte_cuchareta
# [4] -> mal_formaciones
# [5] -> marca_madurez
# [6] -> plaga_enfermedades
# --------------------

# %% [markdown]
# 15. Análisis de Optimización: Comparativa de Pesos

# %%
import matplotlib.pyplot as plt
import os

# Configuración de rutas para guardar la gráfica
img_save_path = "/content/drive/MyDrive/Entrenamiento con balanceo/ResNet50"
os.makedirs(img_save_path, exist_ok=True)

# Obtener tamaños de archivo en MB
keras_size = os.path.getsize(BEST_MODEL_PATH) / (1024 * 1024)
tflite_size = os.path.getsize(tflite_path) / (1024 * 1024)

# Datos para el gráfico
models_comparison = ['Keras (.keras)', 'TFLite (.tflite)']
sizes = [keras_size, tflite_size]
colors = ['#1f77b4', '#2ca02c']  # Azul y Verde

# ===== Gráfico de comparación de tamaños =====
plt.figure(figsize=(8, 6))
bars = plt.bar(models_comparison, sizes, color=colors, width=0.5)

plt.ylabel('Tamaño en MB', fontsize=12)
plt.title(f'Optimización de Modelo: ResNet50W\nReducción: {100 * (1 - tflite_size/keras_size):.1f}%', fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Añadir etiquetas de valor sobre las barras
for bar in bars:
    yval = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        yval + 0.2,
        f'{yval:.2f} MB',
        ha='center',
        va='bottom',
        fontsize=12,
        fontweight='bold'
    )

plt.tight_layout()

# Guardar la gráfica
output_chart_path = os.path.join(img_save_path, "model_size_comparison_efficientnetb0.png")
plt.savefig(output_chart_path, dpi=300, bbox_inches='tight')

print(f"📊 Gráfico de comparación guardado en: {output_chart_path}")
plt.show()
# Out:
# 📊 Gráfico de comparación guardado en: /content/drive/MyDrive/Entrenamiento con balanceo/ResNet50/model_size_comparison_efficientnetb0.png
